# %% [markdown]
# ### Simple Recommender System for new anime file

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#loading the dataset
anime_data = pd.read_csv('../DATA/Anime_new_cleaned.csv')

# %%
#viewing the data
anime_data.head(3)
# Out:
#    anime_id                           title  \
# 0         1                    Cowboy Bebop
# 1         5  Cowboy Bebop Tengoku no Tobira
# 2         6                          Trigun
#
#                                               genres  \
# 0  ['Action','Adventure','Comedy','Drama','SciFi'...
# 1       ['Action','Space','Drama','Mystery','SciFi']
# 2  ['Action','SciFi','Adventure','Comedy','Drama'...
#
#                                             synopsis anime_type  \
# 0  In the year 2071, humanity has colonized sever...         TV
# 1  Another day, another bountysuch is the life of...      Movie
# 2  Vash the Stampede is the man with a 60,000,000...         TV
#
#                      producer    studio  rating  scored_by  popularity  \
# 0            ['BandaiVisual']   Sunrise    8.81   363889.0        39.0
# 1  ['Sunrise','BandaiVisual']     Bones    8.41   111187.0       475.0
# 2     ['VictorEntertainment']  Madhouse    8.31   197451.0       158.0
#
#     members  num_of_episodes anime_source                        aired  \
# 0  704490.0             26.0     Original  Apr 3, 1998 to Apr 24, 1999
# 1  179899.0              1.0     Original                  Sep 1, 2001
# 2  372709.0             26.0        Manga  Apr 1, 1998 to Sep 30, 1998
#
#                                                 Link
# 0       https://myanimelist.net/anime/1/Cowboy_Bebop
# 1  https://myanimelist.net/anime/5/Cowboy_Bebop__...
# 2             https://myanimelist.net/anime/6/Trigun

# %% [markdown]
# ## The features of the dataset are as follows:
# #### -Anime_id : anime Id (as per myanimelist.net)
# #### -Title : name of anime
# #### -Genre : Main genre
# #### -Synopsis : Brief Discription
# #### -Rating : Rating of anime as per myanimelist.net/
# #### -ScoredBy : Total number of users who scored the given anime
# #### -Popularity : Rank of anime based on popularity
# #### -Members : Number of members added given anime on their list
# #### -Episodes : Number of episodes

# %%
anime_data.shape
# Out:
# (15832, 15)

# %% [markdown]
# ### Removing the camel-casing of the column names

# %%
anime_data.columns = map(str.lower, anime_data.columns)
anime_data.head(3)
# Out:
#    anime_id                           title  \
# 0         1                    Cowboy Bebop
# 1         5  Cowboy Bebop Tengoku no Tobira
# 2         6                          Trigun
#
#                                               genres  \
# 0  ['Action','Adventure','Comedy','Drama','SciFi'...
# 1       ['Action','Space','Drama','Mystery','SciFi']
# 2  ['Action','SciFi','Adventure','Comedy','Drama'...
#
#                                             synopsis anime_type  \
# 0  In the year 2071, humanity has colonized sever...         TV
# 1  Another day, another bountysuch is the life of...      Movie
# 2  Vash the Stampede is the man with a 60,000,000...         TV
#
#                      producer    studio  rating  scored_by  popularity  \
# 0            ['BandaiVisual']   Sunrise    8.81   363889.0        39.0
# 1  ['Sunrise','BandaiVisual']     Bones    8.41   111187.0       475.0
# 2     ['VictorEntertainment']  Madhouse    8.31   197451.0       158.0
#
#     members  num_of_episodes anime_source                        aired  \
# 0  704490.0             26.0     Original  Apr 3, 1998 to Apr 24, 1999
# 1  179899.0              1.0     Original                  Sep 1, 2001
# 2  372709.0             26.0        Manga  Apr 1, 1998 to Sep 30, 1998
#
#                                                 link
# 0       https://myanimelist.net/anime/1/Cowboy_Bebop
# 1  https://myanimelist.net/anime/5/Cowboy_Bebop__...
# 2             https://myanimelist.net/anime/6/Trigun

# %%
#checking the datatype of each column
anime_data.dtypes
# Out:
# anime_id             int64
# title               object
# genres              object
# synopsis            object
# anime_type          object
# producer            object
# studio              object
# rating             float64
# scored_by          float64
# popularity         float64
# members            float64
# num_of_episodes    float64
# anime_source        object
# aired               object
# link                object
# dtype: object

# %% [markdown]
# ## Some columns like rating, scoredby, popularity, members, episodes need to be typecasted as integers. We'll convert them once we clean all the data.

# %%
#creating the function to remove the characters
import re
def clean_up(s):
    return re.sub(r"[^\sa-zA-Z0-9\.\,\;\!\-]","",str(s))

# %%
anime_data['title'] = anime_data['title'].apply(clean_up)
anime_data['genres'] = anime_data['genres'].apply(clean_up)
anime_data['producer'] = anime_data['producer'].apply(clean_up)
anime_data['studio'] = anime_data['studio'].apply(clean_up)

# %%
#viewing the cleaned data
anime_data.head(3)
# Out:
#    anime_id                           title  \
# 0         1                    Cowboy Bebop
# 1         5  Cowboy Bebop Tengoku no Tobira
# 2         6                          Trigun
#
#                                         genres  \
# 0    Action,Adventure,Comedy,Drama,SciFi,Space
# 1             Action,Space,Drama,Mystery,SciFi
# 2  Action,SciFi,Adventure,Comedy,Drama,Shounen
#
#                                             synopsis anime_type  \
# 0  In the year 2071, humanity has colonized sever...         TV
# 1  Another day, another bountysuch is the life of...      Movie
# 2  Vash the Stampede is the man with a 60,000,000...         TV
#
#                producer    studio  rating  scored_by  popularity   members  \
# 0          BandaiVisual   Sunrise    8.81   363889.0        39.0  704490.0
# 1  Sunrise,BandaiVisual     Bones    8.41   111187.0       475.0  179899.0
# 2   VictorEntertainment  Madhouse    8.31   197451.0       158.0  372709.0
#
#    num_of_episodes anime_source                        aired  \
# 0             26.0     Original  Apr 3, 1998 to Apr 24, 1999
# 1              1.0     Original                  Sep 1, 2001
# 2             26.0        Manga  Apr 1, 1998 to Sep 30, 1998
#
#                                                 link
# 0       https://myanimelist.net/anime/1/Cowboy_Bebop
# 1  https://myanimelist.net/anime/5/Cowboy_Bebop__...
# 2             https://myanimelist.net/anime/6/Trigun

# %% [markdown]
# ### For the Weighted Score Recommendation System we only need a few columns from the above dataset

# %%
#accessing a limited number of columns required for weighted score recommendation
anime_data = anime_data[['title','genres','rating','scored_by','members']]
anime_data.head(2)
# Out:
#                             title                                     genres  \
# 0                    Cowboy Bebop  Action,Adventure,Comedy,Drama,SciFi,Space
# 1  Cowboy Bebop Tengoku no Tobira           Action,Space,Drama,Mystery,SciFi
#
#    rating  scored_by   members
# 0    8.81   363889.0  704490.0
# 1    8.41   111187.0  179899.0

# %%
#checking for null values
anime_data.isnull().sum()
# Out:
# title           0
# genres          0
# rating       2501
# scored_by    3700
# members         0
# dtype: int64

# %%
anime_data.shape
# Out:
# (15832, 5)

# %% [markdown]
# ### Using a delimiter for 'members' to be greater than 500 members

# %%
anime_data =  anime_data[anime_data['members']>=1000]
anime_data
# Out:
#                                   title  \
# 0                          Cowboy Bebop
# 1        Cowboy Bebop Tengoku no Tobira
# 2                                Trigun
# 3                    Witch Hunter Robin
# 4                        Bouken Ou Beet
# ...                                 ...
# 15811                          Mega Man
# 15812                    AKo The Versus
# 15813       Magic Knight Rayearth Omake
# 15814  Rilu Rilu Fairilu Yousei no Door
# 15819       Agitated Screams of Maggots
#
#                                                genres  rating  scored_by  \
# 0           Action,Adventure,Comedy,Drama,SciFi,Space    8.81   363889.0
# 1                    Action,Space,Drama,Mystery,SciFi    8.41   111187.0
# 2         Action,SciFi,Adventure,Comedy,Drama,Shounen    8.31   197451.0
# 3      Action,Magic,Police,Supernatural,Drama,Mystery    7.34    31875.0
# 4              Adventure,Fantasy,Shounen,Supernatural    7.04     4757.0
# ...                                               ...     ...        ...
# 15811                                             nan    6.52        NaN
# 15812                                             nan    6.49        NaN
# 15813                                             nan    6.45        NaN
# 15814                                             nan    6.36        NaN
# 15819                                             nan    4.45        NaN
#
#         members
# 0      704490.0
# 1      179899.0
# 2      372709.0
# 3       74889.0
# 4       11247.0
# ...         ...
# 15811    3263.0
# 15812    2457.0
# 15813    1730.0
# 15814    1293.0
# 15819    2921.0
#
# [7823 rows x 5 columns]

# %% [markdown]
# ### Let's drop all the rows with NaN's. They will not help us with predicting

# %%
anime_data = anime_data.dropna(axis=0)
anime_data.head()
# Out:
#                             title  \
# 0                    Cowboy Bebop
# 1  Cowboy Bebop Tengoku no Tobira
# 2                          Trigun
# 3              Witch Hunter Robin
# 4                  Bouken Ou Beet
#
#                                            genres  rating  scored_by   members
# 0       Action,Adventure,Comedy,Drama,SciFi,Space    8.81   363889.0  704490.0
# 1                Action,Space,Drama,Mystery,SciFi    8.41   111187.0  179899.0
# 2     Action,SciFi,Adventure,Comedy,Drama,Shounen    8.31   197451.0  372709.0
# 3  Action,Magic,Police,Supernatural,Drama,Mystery    7.34    31875.0   74889.0
# 4          Adventure,Fantasy,Shounen,Supernatural    7.04     4757.0   11247.0

# %%
anime_data.shape
# Out:
# (6415, 5)

# %% [markdown]
# ## 'rating' , 'scoredby' , 'members' and 'episodes' need to be integers.

# %%
anime_data = anime_data.astype({'scored_by':'int64','members':'int64'})
anime_data.head()
# Out:
#                             title  \
# 0                    Cowboy Bebop
# 1  Cowboy Bebop Tengoku no Tobira
# 2                          Trigun
# 3              Witch Hunter Robin
# 4                  Bouken Ou Beet
#
#                                            genres  rating  scored_by  members
# 0       Action,Adventure,Comedy,Drama,SciFi,Space    8.81     363889   704490
# 1                Action,Space,Drama,Mystery,SciFi    8.41     111187   179899
# 2     Action,SciFi,Adventure,Comedy,Drama,Shounen    8.31     197451   372709
# 3  Action,Magic,Police,Supernatural,Drama,Mystery    7.34      31875    74889
# 4          Adventure,Fantasy,Shounen,Supernatural    7.04       4757    11247

# %%
#checking out the number of unique animes
anime_data['title'].nunique()
# Out:
# 6346

# %%
anime_data = anime_data.drop_duplicates()
anime_data= anime_data.reset_index()
anime_data = anime_data.drop(columns='index')
anime_data.head()
# Out:
#                             title  \
# 0                    Cowboy Bebop
# 1  Cowboy Bebop Tengoku no Tobira
# 2                          Trigun
# 3              Witch Hunter Robin
# 4                  Bouken Ou Beet
#
#                                            genres  rating  scored_by  members
# 0       Action,Adventure,Comedy,Drama,SciFi,Space    8.81     363889   704490
# 1                Action,Space,Drama,Mystery,SciFi    8.41     111187   179899
# 2     Action,SciFi,Adventure,Comedy,Drama,Shounen    8.31     197451   372709
# 3  Action,Magic,Police,Supernatural,Drama,Mystery    7.34      31875    74889
# 4          Adventure,Fantasy,Shounen,Supernatural    7.04       4757    11247

# %% [markdown]
# # A recommender system that recommends the highest rated anime to a user

# %% [markdown]
# Using the Weighted Average Formula AND the members column based on popularity
# WR = (RV + Cm/V+m) where:
# - V is the number of votes
# - m is minimum votes required to be listed
# - R is rating average of the anime
# - C is mean vote across whole report

# %%
#finding the weighted average for each anime
V = anime_data['scored_by']                       #number of votes for each anime
R = anime_data['rating']                     #average voting rating for each anime
C = anime_data['rating'].mean()              #mean vote across the whole report
m = anime_data['scored_by'].quantile(0.80)        #minimum votes requires to be among the top 

anime_data['weighted_avg'] = ((R*V)+(C*m))/(V+m)     #used by imdb to calculate weighted average of movies

# %%
anime_data.head()
# Out:
#                             title  \
# 0                    Cowboy Bebop
# 1  Cowboy Bebop Tengoku no Tobira
# 2                          Trigun
# 3              Witch Hunter Robin
# 4                  Bouken Ou Beet
#
#                                            genres  rating  scored_by  members  \
# 0       Action,Adventure,Comedy,Drama,SciFi,Space    8.81     363889   704490
# 1                Action,Space,Drama,Mystery,SciFi    8.41     111187   179899
# 2     Action,SciFi,Adventure,Comedy,Drama,Shounen    8.31     197451   372709
# 3  Action,Magic,Police,Supernatural,Drama,Mystery    7.34      31875    74889
# 4          Adventure,Fantasy,Shounen,Supernatural    7.04       4757    11247
#
#    weighted_avg
# 0      8.690471
# 1      8.141510
# 2      8.156876
# 3      7.164894
# 4      6.956323

# %%
#recommending the top 10 anime with the highest weighted average
wavg = anime_data.sort_values('weighted_avg', ascending = False)
wavg.head()
# Out:
#                                 title  \
# 2688  Fullmetal Alchemist Brotherhood
# 5396                   Kimi no Na wa.
# 3313                      Steins;Gate
# 3658             Hunter x Hunter 2011
# 2506              Clannad After Story
#
#                                                  genres  rating  scored_by  \
# 2688  Action,Military,Adventure,Comedy,Drama,Magic,F...    9.25     730784
# 5396                  Supernatural,Drama,Romance,School    9.19     467437
# 3313                                     Thriller,SciFi    9.14     561405
# 3658                Action,Adventure,SuperPower,Shounen    9.11     400879
# 2506      SliceofLife,Comedy,Supernatural,Drama,Romance    9.01     362434
#
#       members  weighted_avg
# 2688  1194518      9.174036
# 5396   724490      9.076429
# 3313  1005781      9.046752
# 3658   716409      8.983343
# 2506   605864      8.877188

# %%
#plotting the top 10 anime according to weighted average
plt.figure(figsize=(18,8))

ax = sns.barplot(x = wavg['weighted_avg'].head(10), y = wavg['title'].head(10), data =wavg, palette='dark')

plt.title('Best anime by average rating', weight = 'bold')
plt.xlabel('Weighted Average Score', weight = 'bold')
plt.ylabel('Anime Title', weight = 'bold')

#plt.savefig('best_anime using weighted avg.png')
# Out:
# Text(0, 0.5, 'Anime Title')

# %% [markdown]
# ### Recommending according to the anime with the largest members

# %%
#sorting data according to their popularity
anime_members = anime_data.sort_values('members',ascending = False)
anime_members.head(20)
# Out:
#                                 title  \
# 1177                       Death Note
# 4043               Shingeki no Kyojin
# 3710                 Sword Art Online
# 2688  Fullmetal Alchemist Brotherhood
# 5016                    One Punch Man
# 4530                      Tokyo Ghoul
# 2943                      Angel Beats
# 3313                      Steins;Gate
# 1209   Code Geass Hangyaku no Lelouch
# 10                             Naruto
# 4321                  No Game No Life
# 3561                      Mirai Nikki
# 2525                         Toradora
# 3400                   Ao no Exorcist
# 4360                         Noragami
# 193                        Elfen Lied
# 4504              Sword Art Online II
# 231                            Bleach
# 2961                       Fairy Tail
# 1338                Naruto Shippuuden
#
#                                                  genres  rating  scored_by  \
# 1177  Mystery,Police,Psychological,Supernatural,Thri...    8.67    1006242
# 4043  Action,Military,Mystery,SuperPower,Drama,Fanta...    8.49     936784
# 3710              Action,Adventure,Fantasy,Game,Romance    7.64     913806
# 2688  Action,Military,Adventure,Comedy,Drama,Magic,F...    9.25     730784
# 5016  Action,SciFi,Comedy,Parody,SuperPower,Supernat...    8.73     687965
# 4530  Action,Mystery,Horror,Psychological,Supernatur...    8.01     656039
# 2943            Action,Comedy,Drama,School,Supernatural    8.31     640177
# 3313                                     Thriller,SciFi    9.14     561405
# 1209  Action,Military,SciFi,SuperPower,Drama,Mecha,S...    8.79     625466
# 10    Action,Adventure,Comedy,SuperPower,MartialArts...    7.88     645672
# 4321   Game,Adventure,Comedy,Supernatural,Ecchi,Fantasy    8.41     620456
# 3561  Action,Psychological,Supernatural,Thriller,Mys...    7.89     591121
# 2525                  SliceofLife,Comedy,Romance,School    8.39     556177
# 3400         Action,Demons,Fantasy,Shounen,Supernatural    7.83     520377
# 4360       Action,Adventure,Comedy,Supernatural,Shounen    8.15     499984
# 193   Action,Horror,Psychological,Supernatural,Drama...    7.76     513467
# 4504              Action,Game,Adventure,Romance,Fantasy    7.20     528708
# 231   Action,Adventure,Comedy,SuperPower,Supernatura...    7.90     432031
# 2961      Action,Adventure,Comedy,Magic,Fantasy,Shounen    8.08     422524
# 1338  Action,Adventure,Comedy,SuperPower,MartialArts...    8.17     382477
#
#       members  weighted_avg
# 1177  1451708      8.628310
# 4043  1340641      8.449950
# 3710  1297309      7.621475
# 2688  1194518      9.174036
# 5016  1015163      8.667603
# 4530  1008192      7.970957
# 2943  1007952      8.258814
# 3313  1005781      9.046752
# 1209   983674      8.719313
# 10     975394      7.845171
# 4321   966110      8.353399
# 3561   961215      7.851683
# 2525   907550      8.327993
# 3400   860202      7.789447
# 4360   842558      8.092718
# 193    831141      7.722158
# 4504   827221      7.188341
# 231    817079      7.847797
# 2961   816039      8.016689
# 1338   790063      8.094973

# %%
#plotting the top 10 anime according to their members
plt.figure(figsize=(18,8))

ax = sns.barplot(x = anime_members['members'].head(10), y = anime_members['title'].head(10), data = anime_members, palette='muted')

plt.title('Best anime by number of members', weight = 'bold')
plt.xlabel('Number of members', weight = 'bold')
plt.ylabel('Anime Title', weight = 'bold')

#plt.savefig('best_anime using members.png')
# Out:
# Text(0, 0.5, 'Anime Title')

# %% [markdown]
# # Recommending Anime according to the weighted ratings and members

# %%
#recommending movies based on weighted average and popularity
#normalizing the weighted average and popularity column

from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
data_scaled = min_max_scaler.fit_transform(anime_data[['weighted_avg','members']])
data_norm = pd.DataFrame(data_scaled, columns = ['weighted_avg','members'])
data_norm.head()
# Out:
#    weighted_avg   members
# 0      0.892790  0.484928
# 1      0.771082  0.123318
# 2      0.774489  0.256225
# 3      0.554560  0.050932
# 4      0.508319  0.007063

# %%
#creating a score value that splits scaled weighted_avg and popularity in half
anime_data[['norm_weighted_avg','norm_members']] = data_norm
anime_data['score'] = anime_data['norm_weighted_avg']*0.5 + anime_data['norm_members']*0.5
data_scored = anime_data.sort_values(['score'], ascending=False)
data_scored.head()
# Out:
#                                 title  \
# 1177                       Death Note
# 2688  Fullmetal Alchemist Brotherhood
# 4043               Shingeki no Kyojin
# 3313                      Steins;Gate
# 5016                    One Punch Man
#
#                                                  genres  rating  scored_by  \
# 1177  Mystery,Police,Psychological,Supernatural,Thri...    8.67    1006242
# 2688  Action,Military,Adventure,Comedy,Drama,Magic,F...    9.25     730784
# 4043  Action,Military,Mystery,SuperPower,Drama,Fanta...    8.49     936784
# 3313                                     Thriller,SciFi    9.14     561405
# 5016  Action,SciFi,Comedy,Parody,SuperPower,Supernat...    8.73     687965
#
#       members  weighted_avg  norm_weighted_avg  norm_members     score
# 1177  1451708      8.628310           0.879009      1.000000  0.939504
# 2688  1194518      9.174036           1.000000      0.822714  0.911357
# 4043  1340641      8.449950           0.839465      0.923439  0.881452
# 3313  1005781      9.046752           0.971780      0.692614  0.832197
# 5016  1015163      8.667603           0.887720      0.699081  0.793401

# %%
#showing the normalized features and the new score  feature
data_scored[['title','norm_weighted_avg','norm_members','score']].head()
# Out:
#                                 title  norm_weighted_avg  norm_members  \
# 1177                       Death Note           0.879009      1.000000
# 2688  Fullmetal Alchemist Brotherhood           1.000000      0.822714
# 4043               Shingeki no Kyojin           0.839465      0.923439
# 3313                      Steins;Gate           0.971780      0.692614
# 5016                    One Punch Man           0.887720      0.699081
#
#          score
# 1177  0.939504
# 2688  0.911357
# 4043  0.881452
# 3313  0.832197
# 5016  0.793401

# %%
#plotting the top movies according to an even split between weighted avg and popularity

plt.figure(figsize=(18,8))

ax = sns.barplot(x = data_scored['score'].head(10), y = data_scored['title'].head(10), data = data_scored, palette='Set2')


plt.title('Best anime according to average,popularity and members', weight = 'bold')
plt.xlabel('Score', weight = 'bold')
plt.ylabel('Movie Title', weight = 'bold')

#plt.savefig('scored.png')
# Out:
# Text(0, 0.5, 'Movie Title')

# %% [markdown]
# ## Geting the best anime based on genres

# %%
data_scored.head()
# Out:
#                                 title  \
# 1177                       Death Note
# 2688  Fullmetal Alchemist Brotherhood
# 4043               Shingeki no Kyojin
# 3313                      Steins;Gate
# 5016                    One Punch Man
#
#                                                  genres  rating  scored_by  \
# 1177  Mystery,Police,Psychological,Supernatural,Thri...    8.67    1006242
# 2688  Action,Military,Adventure,Comedy,Drama,Magic,F...    9.25     730784
# 4043  Action,Military,Mystery,SuperPower,Drama,Fanta...    8.49     936784
# 3313                                     Thriller,SciFi    9.14     561405
# 5016  Action,SciFi,Comedy,Parody,SuperPower,Supernat...    8.73     687965
#
#       members  weighted_avg  norm_weighted_avg  norm_members     score
# 1177  1451708      8.628310           0.879009      1.000000  0.939504
# 2688  1194518      9.174036           1.000000      0.822714  0.911357
# 4043  1340641      8.449950           0.839465      0.923439  0.881452
# 3313  1005781      9.046752           0.971780      0.692614  0.832197
# 5016  1015163      8.667603           0.887720      0.699081  0.793401

# %%
#resetting the index to match accordingly
data_scored = data_scored.drop_duplicates()
data_scored= data_scored.reset_index()
data_scored = data_scored.drop(columns='index')
data_scored.head()
# Out:
#                              title  \
# 0                       Death Note
# 1  Fullmetal Alchemist Brotherhood
# 2               Shingeki no Kyojin
# 3                      Steins;Gate
# 4                    One Punch Man
#
#                                               genres  rating  scored_by  \
# 0  Mystery,Police,Psychological,Supernatural,Thri...    8.67    1006242
# 1  Action,Military,Adventure,Comedy,Drama,Magic,F...    9.25     730784
# 2  Action,Military,Mystery,SuperPower,Drama,Fanta...    8.49     936784
# 3                                     Thriller,SciFi    9.14     561405
# 4  Action,SciFi,Comedy,Parody,SuperPower,Supernat...    8.73     687965
#
#    members  weighted_avg  norm_weighted_avg  norm_members     score
# 0  1451708      8.628310           0.879009      1.000000  0.939504
# 1  1194518      9.174036           1.000000      0.822714  0.911357
# 2  1340641      8.449950           0.839465      0.923439  0.881452
# 3  1005781      9.046752           0.971780      0.692614  0.832197
# 4  1015163      8.667603           0.887720      0.699081  0.793401

# %%
#function to convert title,genre column to lower case
def lower(x):
    return x.lower()

# %%
data_scored['title'] = data_scored['title'].apply(lower)
data_scored['genres'] = data_scored['genres'].apply(lower)
data_scored.head()
# Out:
#                              title  \
# 0                       death note
# 1  fullmetal alchemist brotherhood
# 2               shingeki no kyojin
# 3                      steins;gate
# 4                    one punch man
#
#                                               genres  rating  scored_by  \
# 0  mystery,police,psychological,supernatural,thri...    8.67    1006242
# 1  action,military,adventure,comedy,drama,magic,f...    9.25     730784
# 2  action,military,mystery,superpower,drama,fanta...    8.49     936784
# 3                                     thriller,scifi    9.14     561405
# 4  action,scifi,comedy,parody,superpower,supernat...    8.73     687965
#
#    members  weighted_avg  norm_weighted_avg  norm_members     score
# 0  1451708      8.628310           0.879009      1.000000  0.939504
# 1  1194518      9.174036           1.000000      0.822714  0.911357
# 2  1340641      8.449950           0.839465      0.923439  0.881452
# 3  1005781      9.046752           0.971780      0.692614  0.832197
# 4  1015163      8.667603           0.887720      0.699081  0.793401

# %%
data_scored.shape
# Out:
# (6368, 9)

# %%
#splitting the genre column into lists
def split_columns(x):
      return x.split(',')

# %%
data_scored['genres'] = data_scored['genres'].apply(split_columns)

# %%
data_scored.head()
# Out:
#                              title  \
# 0                       death note
# 1  fullmetal alchemist brotherhood
# 2               shingeki no kyojin
# 3                      steins;gate
# 4                    one punch man
#
#                                               genres  rating  scored_by  \
# 0  [mystery, police, psychological, supernatural,...    8.67    1006242
# 1  [action, military, adventure, comedy, drama, m...    9.25     730784
# 2  [action, military, mystery, superpower, drama,...    8.49     936784
# 3                                  [thriller, scifi]    9.14     561405
# 4  [action, scifi, comedy, parody, superpower, su...    8.73     687965
#
#    members  weighted_avg  norm_weighted_avg  norm_members     score
# 0  1451708      8.628310           0.879009      1.000000  0.939504
# 1  1194518      9.174036           1.000000      0.822714  0.911357
# 2  1340641      8.449950           0.839465      0.923439  0.881452
# 3  1005781      9.046752           0.971780      0.692614  0.832197
# 4  1015163      8.667603           0.887720      0.699081  0.793401

# %%
data_scored.dtypes
# Out:
# title                 object
# genres                object
# rating               float64
# scored_by              int64
# members                int64
# weighted_avg         float64
# norm_weighted_avg    float64
# norm_members         float64
# score                float64
# dtype: object

# %%
#mapping each title to its genre
anime_map = dict(zip(range(data_scored.shape[0]),data_scored['genres']))

# %%
anime_map
# Out:
# {0: ['mystery',
#   'police',
#   'psychological',
#   'supernatural',
#   'thriller',
#   'shounen'],
#  1: ['action',
#   'military',
#   'adventure',
#   'comedy',
#   'drama',
#   'magic',
#   'fantasy',
#   'shounen'],
#  2: ['action',
#   'military',
#   'mystery',
#   'superpower',
#   'drama',
#   'fantasy',
#   'shounen'],
#  3: ['thriller', 'scifi'],
#  4: ['action',
#   'scifi',
#   'comedy',
#   'parody',
#   'superpower',
#   'supernatural',
#   'seinen'],
#  5: ['action', 'military', 'scifi', 'superpower', 'drama', 'mecha', 'school'],
#  6: ['action', 'adventure', 'fantasy', 'game', 'romance'],
#  7: ['action', 'comedy', 'drama', 'school', 'supernatural'],
#  8: ['game', 'adventure', 'comedy', 'supernatural', 'ecchi', 'fantasy'],
#  9: ['supernatural', 'drama', 'romance', 'school'],
#  10: ['action', 'military', 'scifi', 'superpower', 'drama', 'mecha'],
#  11: ['action', 'adventure', 'superpower', 'shounen'],
#  12: ['sliceoflife', 'comedy', 'romance', 'school'],
#  13: ['action',
#   'mystery',
#   'horror',
#   'psychological',
#   'supernatural',
#   'drama',
#   'seinen'],
#  14: ['action', 'adventure', 'comedy', 'mecha', 'scifi'],
#  15: ['adventure', 'supernatural', 'drama'],
#  16: ['drama', 'music', 'romance', 'school', 'shounen'],
#  17: ['action', 'adventure', 'comedy', 'drama', 'scifi', 'space'],
#  18: ['action', 'adventure', 'comedy', 'superpower', 'martialarts', 'shounen'],
#  19: ['action',
#   'psychological',
#   'supernatural',
#   'thriller',
#   'mystery',
#   'shounen'],
#  20: ['sliceoflife', 'comedy', 'supernatural', 'drama', 'romance'],
#  21: ['action', 'comedy', 'school', 'shounen', 'superpower'],
#  22: ['action', 'adventure', 'comedy', 'supernatural', 'shounen'],
#  23: ['action',
#   'adventure',
#   'comedy',
#   'drama',
#   'fantasy',
#   'magic',
#   'military',
#   'shounen'],
#  24: ['action',
#   'adventure',
#   'comedy',
#   'superpower',
#   'drama',
#   'fantasy',
#   'shounen'],
#  25: ['mystery', 'psychological', 'seinen', 'supernatural'],
#  26: ['psychological', 'drama', 'thriller', 'fantasy'],
#  27: ['action', 'adventure', 'comedy', 'magic', 'fantasy', 'shounen'],
#  28: ['action', 'adventure', 'comedy', 'superpower', 'martialarts', 'shounen'],
#  29: ['action', 'scifi', 'horror', 'psychological', 'drama', 'seinen'],
#  30: ['action', 'mystery', 'supernatural'],
#  31: ['sliceoflife', 'supernatural', 'drama'],
#  32: ['action', 'comedy', 'superpower', 'ecchi', 'school'],
#  33: ['action', 'demons', 'fantasy', 'shounen', 'supernatural'],
#  34: ['drama', 'school', 'shounen'],
#  35: ['sliceoflife', 'comedy', 'romance', 'supernatural', 'school', 'drama'],
#  36: ['action', 'comedy', 'superpower', 'school', 'shounen'],
#  37: ['action', 'fantasy', 'comedy', 'supernatural', 'shounen'],
#  38: ['action', 'supernatural', 'magic', 'fantasy'],
#  39: ['action',
#   'adventure',
#   'comedy',
#   'superpower',
#   'supernatural',
#   'shounen'],
#  40: ['action',
#   'military',
#   'mystery',
#   'superpower',
#   'drama',
#   'fantasy',
#   'shounen'],
#  41: ['ecchi', 'school', 'shounen'],
#  42: ['drama', 'magic', 'psychological', 'thriller'],
#  43: ['romance', 'supernatural', 'mystery', 'vampire'],
#  44: ['action',
#   'horror',
#   'psychological',
#   'supernatural',
#   'drama',
#   'romance',
#   'seinen'],
#  45: ['action', 'adventure', 'fantasy'],
#  46: ['action', 'scifi', 'dementia', 'psychological', 'drama', 'mecha'],
#  47: ['game', 'mystery', 'psychological', 'drama', 'thriller'],
#  48: ['action', 'adventure', 'drama', 'fantasy', 'shounen'],
#  49: ['action',
#   'adventure',
#   'supernatural',
#   'magic',
#   'ecchi',
#   'fantasy',
#   'shounen'],
#  50: ['action',
#   'scifi',
#   'comedy',
#   'historical',
#   'parody',
#   'samurai',
#   'shounen'],
#  51: ['adventure', 'drama', 'fantasy', 'romance'],
#  52: ['action', 'supernatural', 'magic', 'fantasy'],
#  53: ['action', 'adventure', 'comedy', 'historical', 'samurai', 'shounen'],
#  54: ['comedy', 'drama', 'school', 'shounen', 'sports'],
#  55: ['action', 'adventure', 'comedy', 'supernatural', 'shounen'],
#  56: ['comedy', 'harem', 'romance', 'school', 'shoujo'],
#  57: ['action', 'comedy', 'school', 'shounen'],
#  58: ['action', 'sliceoflife', 'comedy', 'supernatural'],
#  59: ['adventure', 'comedy', 'parody', 'supernatural', 'magic', 'fantasy'],
#  60: ['comedy', 'demons', 'supernatural', 'romance', 'fantasy'],
#  61: ['action', 'scifi', 'mystery', 'superpower'],
#  62: ['action', 'mystery', 'comedy', 'historical', 'supernatural'],
#  63: ['action', 'game', 'adventure', 'romance', 'fantasy'],
#  64: ['comedy', 'romance', 'school', 'shoujo'],
#  65: ['comedy', 'school', 'shounen', 'sports'],
#  66: ['adventure',
#   'fantasy',
#   'historical',
#   'mystery',
#   'seinen',
#   'sliceoflife',
#   'supernatural'],
#  67: ['action', 'game', 'adventure', 'magic', 'fantasy'],
#  68: ['mystery', 'psychological', 'thriller'],
#  69: ['comedy', 'sports', 'drama', 'school', 'shounen'],
#  70: ['sliceoflife', 'fantasy'],
#  71: ['action', 'scifi', 'superpower', 'drama', 'romance'],
#  72: ['action',
#   'comedy',
#   'demons',
#   'fantasy',
#   'historical',
#   'shounen',
#   'supernatural'],
#  73: ['action', 'comedy', 'school', 'shounen'],
#  74: ['scifi', 'adventure', 'mystery', 'drama', 'fantasy'],
#  75: ['comedy', 'drama', 'school', 'shounen', 'sliceoflife'],
#  76: ['adventure', 'fantasy', 'historical', 'romance'],
#  77: ['adventure', 'comedy', 'supernatural'],
#  78: ['sliceoflife', 'comedy', 'drama', 'romance', 'school'],
#  79: ['scifi', 'mystery', 'horror', 'psychological', 'supernatural', 'drama'],
#  80: ['action',
#   'mystery',
#   'horror',
#   'psychological',
#   'supernatural',
#   'drama',
#   'seinen'],
#  81: ['ecchi', 'school', 'shounen'],
#  82: ['adventure', 'comedy', 'parody', 'supernatural', 'magic', 'fantasy'],
#  83: ['action', 'supernatural', 'magic', 'fantasy'],
#  84: ['comedy', 'mystery', 'romance', 'school', 'scifi', 'supernatural'],
#  85: ['action', 'adventure', 'comedy', 'romance', 'fantasy'],
#  86: ['scifi', 'adventure', 'drama', 'romance'],
#  87: ['drama', 'school', 'superpower'],
#  88: ['comedy', 'sports', 'drama', 'school', 'shounen'],
#  89: ['drama',
#   'horror',
#   'mystery',
#   'police',
#   'psychological',
#   'seinen',
#   'thriller'],
#  90: ['sliceoflife', 'comedy', 'school'],
#  91: ['mystery', 'comedy', 'supernatural', 'romance', 'vampire'],
#  92: ['action', 'game', 'adventure', 'supernatural', 'magic', 'fantasy'],
#  93: ['adventure',
#   'comedy',
#   'fantasy',
#   'martialarts',
#   'shounen',
#   'superpower'],
#  94: ['action', 'adventure', 'magic', 'fantasy', 'shounen'],
#  95: ['comedy', 'sports', 'school', 'shounen'],
#  96: ['action', 'seinen'],
#  97: ['comedy', 'psychological', 'drama', 'romance'],
#  98: ['comedy', 'demons', 'ecchi', 'harem', 'romance', 'school'],
#  99: ['sliceoflife', 'supernatural', 'fantasy'],
#  100: ['mystery',
#   'dementia',
#   'horror',
#   'psychological',
#   'supernatural',
#   'thriller'],
#  101: ['sliceoflife', 'drama', 'fantasy'],
#  102: ['sliceoflife', 'comedy', 'music', 'school'],
#  103: ['sliceoflife', 'comedy', 'school'],
#  104: ['comedy', 'romance', 'school'],
#  105: ['action', 'scifi', 'horror', 'shounen'],
#  106: ['harem', 'comedy', 'romance', 'school', 'shounen'],
#  107: ['action', 'adventure', 'comedy', 'superpower', 'demons', 'shounen'],
#  108: ['drama', 'romance', 'shoujo', 'supernatural'],
#  109: ['action', 'scifi', 'adventure', 'comedy', 'drama', 'shounen'],
#  110: ['action',
#   'scifi',
#   'comedy',
#   'historical',
#   'parody',
#   'samurai',
#   'shounen'],
#  111: ['comedy', 'sliceoflife'],
#  112: ['action', 'supernatural', 'magic', 'fantasy'],
#  113: ['drama', 'romance', 'sliceoflife'],
#  114: ['sliceoflife', 'comedy', 'drama', 'romance', 'school'],
#  115: ['scifi', 'drama'],
#  116: ['sliceoflife', 'romance', 'school'],
#  117: ['action', 'adventure', 'comedy', 'fantasy', 'magic', 'shounen'],
#  118: ['comedy', 'sports', 'school', 'shounen'],
#  119: ['scifi', 'dementia', 'psychological', 'drama', 'mecha'],
#  120: ['action',
#   'scifi',
#   'comedy',
#   'parody',
#   'dementia',
#   'psychological',
#   'mecha'],
#  121: ['action', 'scifi', 'police', 'psychological', 'mecha', 'seinen'],
#  122: ['action',
#   'comedy',
#   'historical',
#   'parody',
#   'samurai',
#   'scifi',
#   'shounen'],
#  123: ['mystery', 'comedy', 'supernatural', 'ecchi'],
#  124: ['comedy', 'sports', 'drama', 'shounen'],
#  125: ['action',
#   'adventure',
#   'demons',
#   'drama',
#   'fantasy',
#   'horror',
#   'military',
#   'romance',
#   'seinen',
#   'supernatural'],
#  126: ['comedy', 'drama', 'romance', 'shounen'],
#  127: ['sliceoflife', 'comedy', 'romance', 'school', 'shoujo'],
#  128: ['action', 'comedy', 'shounen', 'superpower'],
#  129: ['action', 'military', 'supernatural', 'drama', 'vampire', 'shounen'],
#  130: ['sliceoflife', 'comedy', 'fantasy'],
#  131: ['josei', 'sliceoflife'],
#  132: ['action', 'comedy', 'demons', 'supernatural', 'martialarts', 'shounen'],
#  133: ['sliceoflife', 'psychological', 'drama', 'romance'],
#  134: ['adventure', 'historical', 'romance', 'fantasy'],
#  135: ['sliceoflife', 'comedy', 'supernatural', 'drama', 'romance', 'school'],
#  136: ['action', 'adventure', 'comedy', 'fantasy', 'romance', 'shoujo'],
#  137: ['drama', 'historical'],
#  138: ['sliceoflife', 'fantasy', 'magic', 'shounen'],
#  139: ['music', 'sliceoflife', 'comedy', 'drama', 'romance', 'shoujo'],
#  140: ['action', 'adventure', 'comedy', 'historical', 'romance', 'samurai'],
#  141: ['comedy', 'drama', 'romance'],
#  142: ['action',
#   'adventure',
#   'superpower',
#   'demons',
#   'supernatural',
#   'fantasy',
#   'shounen'],
#  143: ['action', 'supernatural', 'magic', 'romance', 'fantasy'],
#  144: ['action', 'scifi', 'supernatural', 'magic', 'romance', 'school'],
#  145: ['ecchi', 'school', 'shounen'],
#  146: ['sliceoflife', 'supernatural', 'drama', 'fantasy', 'shoujo'],
#  147: ['drama', 'fantasy', 'romance'],
#  148: ['comedy', 'ecchi', 'romance', 'school', 'seinen'],
#  149: ['scifi', 'comedy'],
#  150: ['comedy', 'music', 'school', 'sliceoflife'],
#  151: ['comedy', 'ecchi', 'fantasy', 'game', 'supernatural'],
#  152: ['mystery', 'psychological', 'supernatural', 'thriller'],
#  153: ['action', 'military', 'scifi', 'adventure', 'horror', 'supernatural'],
#  154: ['action', 'scifi', 'psychological', 'seinen'],
#  155: ['action', 'military', 'scifi', 'police', 'mecha', 'seinen'],
#  156: ['action', 'harem', 'comedy', 'demons', 'romance', 'ecchi', 'school'],
#  157: ['comedy', 'romance', 'shoujo'],
#  158: ['mystery', 'historical', 'drama', 'romance'],
#  159: ['action', 'scifi', 'mecha'],
#  160: ['action', 'military', 'adventure', 'fantasy'],
#  161: ['scifi', 'drama', 'romance'],
#  162: ['action',
#   'adventure',
#   'comedy',
#   'historical',
#   'demons',
#   'supernatural',
#   'magic',
#   'romance',
#   'fantasy',
#   'shounen'],
#  163: ['action',
#   'adventure',
#   'harem',
#   'comedy',
#   'magic',
#   'romance',
#   'ecchi',
#   'fantasy',
#   'school'],
#  164: ['comedy', 'drama', 'romance', 'shounen'],
#  165: ['comedy', 'harem', 'romance', 'shounen', 'supernatural'],
#  166: ['action', 'adventure', 'shounen', 'superpower'],
#  167: ['action', 'seinen'],
#  168: ['action', 'scifi', 'mystery', 'comedy', 'drama', 'romance', 'thriller'],
#  169: ['action', 'historical', 'drama', 'romance', 'martialarts', 'samurai'],
#  170: ['sliceoflife', 'comedy', 'parody', 'school'],
#  171: ['scifi', 'adventure', 'drama', 'romance', 'mecha'],
#  172: ['scifi', 'mystery', 'psychological'],
#  173: ['action', 'comedy', 'school', 'shounen', 'superpower'],
#  174: ['comedy', 'sports'],
#  175: ['comedy', 'romance', 'school', 'superpower'],
#  176: ['action', 'adventure', 'drama', 'shounen', 'supernatural'],
#  177: ['comedy', 'drama', 'romance', 'shounen'],
#  178: ['action', 'adventure', 'comedy', 'supernatural', 'drama', 'shounen'],
#  179: ['action',
#   'comedy',
#   'historical',
#   'parody',
#   'samurai',
#   'scifi',
#   'shounen'],
#  180: ['action', 'magic', 'scifi', 'superpower'],
#  181: ['action', 'game', 'scifi', 'romance', 'school'],
#  182: ['comedy', 'romance', 'shoujo'],
#  183: ['drama', 'historical', 'seinen', 'thriller'],
#  184: ['ecchi', 'sliceoflife', 'comedy', 'harem', 'romance', 'school'],
#  185: ['action', 'comedy', 'demons', 'supernatural', 'school', 'shounen'],
#  186: ['adventure', 'fantasy'],
#  187: ['mystery', 'horror', 'supernatural', 'thriller', 'vampire'],
#  188: ['action', 'scifi', 'mystery', 'seinen'],
#  189: ['psychological', 'drama', 'magic', 'thriller'],
#  190: ['action', 'adventure', 'drama', 'fantasy'],
#  191: ['action',
#   'comedy',
#   'superpower',
#   'supernatural',
#   'vampire',
#   'fantasy',
#   'shounen'],
#  192: ['comedy', 'harem', 'mecha', 'romance', 'school', 'scifi'],
#  193: ['action', 'mystery', 'comedy', 'supernatural', 'seinen'],
#  194: ['comedy', 'drama', 'romance', 'school', 'shoujo', 'sliceoflife'],
#  195: ['action', 'horror', 'supernatural', 'vampire', 'seinen'],
#  196: ['action', 'scifi', 'mecha'],
#  197: ['action',
#   'scifi',
#   'comedy',
#   'historical',
#   'parody',
#   'samurai',
#   'shounen'],
#  198: ['adventure', 'comedy', 'drama', 'magic', 'romance', 'fantasy'],
#  199: ['comedy', 'drama'],
#  200: ['magic', 'military'],
#  201: ['action', 'mystery', 'supernatural'],
#  202: ['action', 'adventure', 'supernatural', 'drama', 'shounen'],
#  203: ['adventure',
#   'comedy',
#   'drama',
#   'magic',
#   'romance',
#   'fantasy',
#   'school',
#   'shoujo'],
#  204: ['mystery', 'psychological', 'school'],
#  205: ['action', 'comedy', 'ecchi', 'harem', 'magic', 'supernatural'],
#  206: ['drama', 'josei', 'music', 'romance', 'school'],
#  207: ['action', 'mystery', 'supernatural', 'vampire'],
#  208: ['mystery', 'comedy', 'psychological', 'romance'],
#  209: ['dementia',
#   'drama',
#   'mystery',
#   'psychological',
#   'scifi',
#   'supernatural'],
#  210: ['scifi', 'thriller'],
#  211: ['harem',
#   'mystery',
#   'comedy',
#   'supernatural',
#   'romance',
#   'school',
#   'shounen'],
#  212: ['mystery', 'comedy', 'supernatural', 'vampire'],
#  213: ['music', 'sliceoflife', 'comedy', 'drama', 'romance', 'josei'],
#  214: ['action', 'space', 'drama', 'mystery', 'scifi'],
#  215: ['action', 'romance', 'ecchi', 'fantasy', 'school'],
#  216: ['adventure',
#   'sliceoflife',
#   'mystery',
#   'historical',
#   'supernatural',
#   'fantasy',
#   'seinen'],
#  217: ['comedy', 'sports', 'drama', 'shounen'],
#  218: ['action', 'mystery', 'supernatural', 'seinen'],
#  219: ['adventure', 'supernatural'],
#  220: ['mystery', 'supernatural', 'vampire'],
#  221: ['scifi', 'drama', 'mecha'],
#  222: ['comedy', 'supernatural', 'romance', 'ecchi'],
#  223: ['sports', 'psychological', 'drama', 'seinen'],
#  224: ['comedy', 'harem', 'romance', 'shounen', 'supernatural'],
#  225: ['drama', 'fantasy', 'shoujo', 'sliceoflife', 'supernatural'],
#  226: ['drama', 'game', 'josei', 'school', 'sliceoflife', 'sports'],
#  227: ['action', 'mystery', 'supernatural', 'vampire'],
#  228: ['action', 'military', 'supernatural', 'drama', 'vampire', 'shounen'],
#  229: ['action', 'comedy', 'fantasy', 'supernatural'],
#  230: ['scifi',
#   'mystery',
#   'dementia',
#   'horror',
#   'psychological',
#   'thriller',
#   'fantasy'],
#  231: ['action', 'adventure', 'historical', 'samurai'],
#  232: ['sliceoflife', 'drama', 'romance', 'school', 'shoujo'],
#  233: ['action', 'military', 'scifi', 'comedy', 'mecha'],
#  234: ['drama', 'fantasy', 'shoujo', 'sliceoflife', 'supernatural'],
#  235: ['scifi', 'music'],
#  236: ['comedy', 'drama', 'music', 'shounen', 'sliceoflife'],
#  237: ['sliceoflife', 'supernatural', 'drama', 'fantasy', 'shoujo'],
#  238: ['game', 'sliceoflife', 'drama', 'seinen'],
#  239: ['adventure', 'comedy', 'fantasy', 'magic', 'school'],
#  240: ['sliceoflife', 'comedy', 'sports', 'drama', 'school'],
#  241: ['sliceoflife', 'comedy'],
#  242: ['action',
#   'adventure',
#   'comedy',
#   'historical',
#   'samurai',
#   'fantasy',
#   'seinen'],
#  243: ['comedy', 'mystery', 'supernatural', 'vampire'],
#  244: ['action', 'military', 'scifi', 'mystery', 'police', 'mecha', 'seinen'],
#  245: ['action', 'comedy', 'school'],
#  246: ['dementia', 'horror', 'psychological', 'drama'],
#  247: ['action', 'fantasy', 'shoujo'],
#  248: ['comedy', 'demons', 'fantasy', 'historical', 'shounen', 'supernatural'],
#  249: ['action', 'game', 'adventure', 'romance', 'fantasy'],
#  250: ['harem', 'comedy', 'supernatural', 'romance', 'shounen'],
#  251: ['action', 'comedy', 'demons', 'ecchi', 'harem', 'romance', 'school'],
#  252: ['sliceoflife', 'comedy', 'drama', 'romance', 'fantasy', 'shoujo'],
#  253: ['adventure', 'fantasy', 'mystery', 'shounen', 'supernatural'],
#  254: ['adventure',
#   'fantasy',
#   'historical',
#   'mystery',
#   'seinen',
#   'sliceoflife',
#   'supernatural'],
#  255: ['drama', 'romance', 'school', 'shoujo'],
#  256: ['action', 'military', 'adventure', 'fantasy'],
#  257: ['fantasy', 'romance', 'drama', 'shoujo'],
#  258: ['action', 'adventure', 'fantasy', 'game', 'magic'],
#  259: ['action', 'adventure', 'supernatural', 'magic', 'fantasy', 'shounen'],
#  260: ['romance', 'school'],
#  261: ['action', 'scifi', 'cars', 'sports'],
#  262: ['drama', 'romance', 'school', 'sliceoflife'],
#  263: ['sliceoflife', 'comedy', 'supernatural', 'school', 'shounen'],
#  264: ['comedy', 'magic', 'fantasy'],
#  265: ['action',
#   'comedy',
#   'historical',
#   'parody',
#   'samurai',
#   'scifi',
#   'shounen'],
#  266: ['action', 'drama', 'historical'],
#  267: ['action', 'military', 'scifi', 'mecha'],
#  268: ['comedy', 'superpower', 'romance', 'school'],
#  269: ['scifi', 'drama', 'romance'],
#  270: ['mystery', 'comedy', 'supernatural', 'ecchi'],
#  271: ['action', 'adventure', 'fantasy', 'game', 'magic', 'supernatural'],
#  272: ['drama', 'historical', 'josei'],
#  273: ['sliceoflife', 'comedy', 'school', 'seinen'],
#  274: ['action', 'comedy', 'martialarts', 'school', 'shounen'],
#  275: ['action', 'mystery', 'supernatural'],
#  276: ['comedy', 'romance', 'school', 'shounen'],
#  277: ['comedy', 'drama', 'romance', 'shoujo'],
#  278: ['action', 'adventure', 'comedy', 'fantasy', 'kids'],
#  279: ['comedy', 'sports', 'drama', 'shounen'],
#  280: ['action', 'scifi', 'police', 'psychological'],
#  281: ['sliceoflife', 'supernatural', 'drama', 'romance'],
#  282: ['action', 'mystery', 'supernatural'],
#  283: ['scifi', 'drama', 'romance', 'school', 'shoujo'],
#  284: ['action', 'drama', 'seinen', 'thriller'],
#  285: ['action', 'drama', 'fantasy', 'horror'],
#  286: ['action', 'adventure', 'fantasy', 'magic', 'mystery'],
#  287: ['comedy', 'drama', 'romance', 'school', 'sliceoflife'],
#  288: ['horror', 'mystery', 'romance', 'school', 'shounen', 'supernatural'],
#  289: ['action', 'scifi', 'space', 'superpower', 'mecha'],
#  290: ['sliceoflife', 'comedy', 'school'],
#  291: ['scifi', 'comedy', 'drama', 'romance', 'ecchi', 'seinen'],
#  292: ['comedy', 'mystery', 'supernatural'],
#  293: ['action', 'supernatural', 'magic', 'fantasy'],
#  294: ['comedy', 'school', 'shounen', 'sliceoflife'],
#  295: ['sliceoflife', 'comedy', 'romance'],
#  296: ['comedy', 'romance', 'school', 'shounen'],
#  297: ['action', 'scifi', 'superpower'],
#  298: ['music', 'school', 'drama'],
#  299: ['adventure', 'mystery', 'comedy', 'police', 'shounen'],
#  300: ['action',
#   'harem',
#   'comedy',
#   'supernatural',
#   'magic',
#   'romance',
#   'ecchi',
#   'fantasy',
#   'school',
#   'shounen'],
#  301: ['comedy', 'parody', 'school'],
#  302: ['action', 'mystery', 'horror', 'supernatural', 'seinen'],
#  303: ['game', 'psychological', 'seinen', 'thriller'],
#  304: ['comedy', 'supernatural', 'romance', 'shounen'],
#  305: ['drama', 'psychological', 'school', 'sliceoflife'],
#  306: ['comedy', 'sports', 'drama', 'school', 'shounen'],
#  307: ['drama', 'harem', 'psychological', 'romance', 'school'],
#  308: ['action', 'military', 'mecha'],
#  309: ['scifi',
#   'harem',
#   'comedy',
#   'supernatural',
#   'romance',
#   'ecchi',
#   'shounen'],
#  310: ['action', 'demons', 'supernatural', 'fantasy', 'shounen'],
#  311: ['drama', 'game', 'josei', 'school', 'sliceoflife', 'sports'],
#  312: ['comedy', 'ecchi', 'school'],
#  313: ['action', 'scifi', 'superpower', 'magic'],
#  314: ['action',
#   'military',
#   'mystery',
#   'horror',
#   'supernatural',
#   'drama',
#   'vampire'],
#  315: ['action',
#   'adventure',
#   'comedy',
#   'fantasy',
#   'martialarts',
#   'shounen',
#   'superpower'],
#  316: ['action', 'demons', 'horror', 'supernatural'],
#  317: ['drama', 'game', 'seinen', 'sliceoflife'],
#  318: ['drama', 'harem', 'psychological', 'romance'],
#  319: ['comedy', 'demons', 'supernatural', 'romance', 'fantasy', 'shoujo'],
#  320: ['action', 'mystery', 'drama', 'fantasy', 'seinen'],
#  321: ['action',
#   'adventure',
#   'comedy',
#   'historical',
#   'demons',
#   'supernatural',
#   'magic',
#   'romance',
#   'fantasy',
#   'shounen'],
#  322: ['sliceoflife', 'comedy', 'drama'],
#  323: ['action', 'military', 'scifi', 'space', 'drama', 'mecha'],
#  324: ['mystery', 'drama', 'romance'],
#  325: ['drama', 'mystery', 'romance', 'shoujo', 'supernatural', 'vampire'],
#  326: ['sliceoflife', 'drama', 'romance', 'shoujo'],
#  327: ['comedy', 'school', 'seinen', 'sliceoflife'],
#  328: ['action', 'scifi', 'mystery', 'superpower'],
#  329: ['comedy', 'school', 'shounen', 'sliceoflife'],
#  330: ['drama', 'magic', 'psychological', 'thriller'],
#  331: ['harem', 'comedy', 'romance', 'ecchi', 'school'],
#  332: ['adventure', 'comedy', 'fantasy', 'magic', 'school'],
#  333: ['mystery', 'comedy', 'dementia', 'psychological', 'drama'],
#  334: ['sliceoflife', 'magic', 'fantasy', 'shounen'],
#  335: ['action', 'adventure', 'comedy', 'supernatural', 'drama', 'shounen'],
#  336: ['sliceoflife', 'adventure'],
#  337: ['drama'],
#  338: ['action', 'adventure', 'drama', 'fantasy', 'mystery', 'scifi'],
#  339: ['action', 'comedy', 'demons', 'supernatural', 'fantasy', 'shounen'],
#  340: ['comedy', 'supernatural', 'magic', 'romance', 'school'],
#  341: ['sliceoflife', 'comedy', 'romance', 'school'],
#  342: ['action', 'adventure', 'comedy', 'drama', 'fantasy', 'shounen'],
#  343: ['action', 'adventure', 'demons', 'fantasy', 'magic', 'supernatural'],
#  344: ['action', 'harem', 'comedy', 'supernatural', 'magic', 'ecchi'],
#  345: ['comedy', 'drama', 'romance', 'school', 'sliceoflife', 'supernatural'],
#  346: ['sports', 'psychological', 'seinen'],
#  347: ['action', 'adventure', 'fantasy', 'magic', 'shounen'],
#  348: ['comedy', 'parody', 'romance', 'school', 'shounen'],
#  349: ['action', 'mystery', 'supernatural', 'thriller'],
#  350: ['comedy', 'drama'],
#  351: ['sliceoflife', 'comedy', 'sports', 'drama', 'school'],
#  352: ['action', 'drama', 'psychological', 'scifi', 'seinen'],
#  353: ['action',
#   'harem',
#   'supernatural',
#   'ecchi',
#   'vampire',
#   'fantasy',
#   'school'],
#  354: ['drama', 'romance', 'school'],
#  355: ['sliceoflife', 'comedy', 'school', 'shounen'],
#  356: ['comedy', 'harem', 'romance', 'school', 'shounen'],
#  357: ['drama', 'game', 'mystery', 'psychological', 'school', 'shounen'],
#  358: ['action', 'mystery', 'comedy', 'historical', 'supernatural'],
#  359: ['action', 'adventure', 'historical', 'drama', 'fantasy', 'shounen'],
#  360: ['drama', 'romance', 'scifi', 'seinen', 'space'],
#  361: ['sliceoflife', 'comedy', 'josei'],
#  362: ['sliceoflife', 'comedy', 'school'],
#  363: ['action', 'adventure', 'comedy', 'kids', 'fantasy'],
#  364: ['action', 'drama', 'fantasy', 'romance', 'school', 'supernatural'],
#  365: ['action', 'adventure', 'seinen'],
#  366: ['action', 'seinen'],
#  367: ['action', 'drama', 'seinen'],
#  368: ['military', 'comedy', 'historical', 'drama', 'fantasy', 'shounen'],
#  369: ['action', 'military', 'scifi', 'fantasy'],
#  370: ['scifi', 'seinen'],
#  371: ['action', 'scifi', 'mystery', 'drama'],
#  372: ['comedy', 'drama', 'josei', 'romance', 'sliceoflife'],
#  373: ['drama', 'romance', 'fantasy', 'shoujo'],
#  374: ['action', 'comedy', 'ecchi', 'shounen', 'sports'],
#  375: ['comedy', 'romance', 'school', 'shoujo'],
#  376: ['action', 'comedy', 'parody', 'supernatural', 'ecchi'],
#  377: ['mystery', 'horror', 'psychological', 'supernatural'],
#  378: ['action', 'cars', 'drama', 'seinen', 'sports'],
#  379: ['drama', 'romance', 'ecchi', 'school', 'seinen'],
#  380: ['harem',
#   'comedy',
#   'romance',
#   'ecchi',
#   'vampire',
#   'fantasy',
#   'school',
#   'shounen'],
#  381: ['game', 'comedy', 'school', 'seinen'],
#  382: ['comedy', 'sports', 'drama', 'romance', 'school', 'shounen'],
#  383: ['mystery',
#   'historical',
#   'horror',
#   'demons',
#   'psychological',
#   'supernatural',
#   'fantasy',
#   'seinen'],
#  384: ['action', 'superpower', 'drama', 'fantasy', 'shounen'],
#  385: ['game', 'comedy', 'romance'],
#  386: ['comedy', 'school', 'shounen'],
#  387: ['sliceoflife', 'comedy', 'romance'],
#  388: ['fantasy'],
#  389: ['harem', 'comedy', 'romance', 'ecchi', 'school'],
#  390: ['comedy', 'harem', 'mecha', 'romance', 'school', 'scifi'],
#  391: ['scifi', 'harem', 'comedy', 'romance', 'ecchi', 'school', 'shounen'],
#  392: ['comedy',
#   'demons',
#   'fantasy',
#   'historical',
#   'mystery',
#   'shounen',
#   'supernatural'],
#  393: ['comedy', 'drama', 'romance', 'shounenai'],
#  394: ['action', 'superpower', 'fantasy'],
#  395: ['action', 'adventure', 'historical', 'fantasy'],
#  396: ['action', 'game'],
#  397: ['sliceoflife', 'supernatural', 'drama'],
#  398: ['drama', 'historical', 'romance'],
#  399: ['drama', 'romance', 'school'],
#  400: ['action', 'magic', 'romance', 'fantasy', 'shounen'],
#  401: ['sliceoflife', 'psychological', 'school', 'horror', 'mystery'],
#  402: ['sliceoflife', 'supernatural', 'fantasy'],
#  403: ['action', 'comedy', 'superpower', 'martialarts', 'shounen'],
#  404: ['action',
#   'adventure',
#   'comedy',
#   'fantasy',
#   'martialarts',
#   'shounen',
#   'superpower'],
#  405: ['comedy', 'romance', 'sliceoflife'],
#  406: ['action',
#   'comedy',
#   'fantasy',
#   'shounen',
#   'superpower',
#   'supernatural',
#   'vampire'],
#  407: ['action',
#   'scifi',
#   'comedy',
#   'historical',
#   'parody',
#   'samurai',
#   'shounen'],
#  408: ['sliceoflife', 'comedy'],
#  409: ['sliceoflife', 'mystery', 'psychological', 'drama', 'fantasy'],
#  410: ['comedy', 'drama', 'romance', 'scifi', 'sliceoflife'],
#  411: ['comedy',
#   'ecchi',
#   'harem',
#   'romance',
#   'scifi',
#   'shounen',
#   'supernatural'],
#  412: ['scifi', 'sliceoflife'],
#  413: ['drama', 'historical', 'josei'],
#  414: ['scifi', 'space', 'comedy'],
#  415: ['comedy', 'school', 'seinen', 'sliceoflife'],
#  416: ['action', 'adventure', 'comedy', 'supernatural', 'shounen'],
#  417: ['action',
#   'drama',
#   'horror',
#   'mystery',
#   'psychological',
#   'seinen',
#   'supernatural'],
#  418: ['harem', 'comedy', 'romance', 'ecchi', 'fantasy', 'seinen'],
#  419: ['comedy', 'romance', 'seinen'],
#  420: ['action', 'superpower', 'romance', 'martialarts', 'shounen'],
#  421: ['action', 'mystery', 'supernatural', 'romance', 'thriller'],
#  422: ['sliceoflife', 'comedy'],
#  423: ['music', 'school', 'sliceoflife'],
#  424: ['game', 'mystery', 'psychological', 'drama', 'thriller'],
#  425: ['action', 'scifi', 'fantasy'],
#  426: ['comedy', 'school', 'shounen', 'sliceoflife'],
#  427: ['action', 'scifi', 'adventure', 'mecha'],
#  428: ['comedy', 'sports', 'drama', 'shounen'],
#  429: ['harem', 'comedy', 'supernatural', 'romance', 'school'],
#  430: ['comedy', 'drama', 'romance', 'shounenai'],
#  431: ['action', 'military', 'scifi', 'space', 'drama', 'mecha'],
#  432: ['adventure',
#   'sliceoflife',
#   'mystery',
#   'historical',
#   'supernatural',
#   'fantasy',
#   'seinen'],
#  433: ['drama', 'mystery', 'scifi', 'supernatural', 'thriller'],
#  434: ['comedy', 'drama', 'romance', 'shounenai'],
#  435: ['comedy', 'vampire', 'fantasy', 'school', 'seinen'],
#  436: ['comedy', 'drama', 'romance', 'school', 'sliceoflife', 'supernatural'],
#  437: ['action', 'adventure', 'fantasy', 'military'],
#  438: ['action', 'mystery', 'comedy', 'superpower'],
#  439: ['sliceoflife', 'supernatural', 'drama', 'fantasy', 'shoujo'],
#  440: ['demons', 'magic', 'romance', 'shoujo'],
#  441: ['comedy', 'romance', 'sliceoflife'],
#  442: ['comedy', 'horror', 'mystery', 'shoujo', 'supernatural'],
#  443: ['comedy', 'school', 'shoujoai', 'sliceoflife'],
#  444: ['comedy', 'romance', 'school'],
#  445: ['music', 'school', 'drama'],
#  446: ['comedy', 'josei', 'music', 'romance'],
#  447: ['mystery', 'psychological', 'drama'],
#  448: ['mystery', 'supernatural', 'drama', 'romance'],
#  449: ['comedy', 'school', 'shounen', 'sports'],
#  450: ['mystery', 'supernatural', 'drama', 'romance', 'vampire', 'shoujo'],
#  451: ['action', 'superpower', 'supernatural'],
#  452: ['comedy', 'drama', 'romance', 'shounenai'],
#  453: ['action', 'comedy', 'supernatural'],
#  454: ['music', 'sliceoflife', 'comedy', 'romance', 'josei'],
#  455: ['action', 'psychological', 'supernatural', 'shounen'],
#  456: ['mystery', 'comedy', 'psychological', 'supernatural', 'drama'],
#  457: ['scifi', 'thriller'],
#  458: ['comedy', 'scifi', 'seinen', 'sliceoflife', 'space'],
#  459: ['scifi', 'drama', 'romance', 'fantasy'],
#  460: ['sliceoflife', 'comedy', 'school', 'shounen'],
#  461: ['action', 'comedy', 'mecha'],
#  462: ['action',
#   'scifi',
#   'comedy',
#   'parody',
#   'superpower',
#   'supernatural',
#   'seinen'],
#  463: ['action', 'adventure', 'shounen', 'superpower'],
#  464: ['action', 'historical', 'demons', 'supernatural', 'romance'],
#  465: ['comedy', 'parody', 'shounen', 'supernatural'],
#  466: ['action', 'mystery', 'horror', 'supernatural', 'seinen'],
#  467: ['game', 'psychological', 'thriller', 'seinen'],
#  468: ['drama'],
#  469: ['ecchi', 'school', 'shounen'],
#  470: ['action', 'mecha', 'scifi', 'seinen', 'space'],
#  471: ['comedy', 'romance', 'shoujo'],
#  472: ['adventure', 'drama', 'fantasy'],
#  473: ['comedy', 'school', 'seinen', 'sliceoflife'],
#  474: ['space', 'comedy', 'scifi'],
#  475: ['action', 'superpower', 'supernatural', 'thriller'],
#  476: ['adventure', 'mystery', 'scifi', 'sliceoflife'],
#  477: ['action', 'demons', 'fantasy', 'shounen', 'supernatural'],
#  478: ['comedy', 'drama', 'fantasy', 'magic', 'romance', 'shoujo'],
#  479: ['sliceoflife', 'comedy', 'romance'],
#  480: ['action', 'magic', 'fantasy', 'school'],
#  481: ['action', 'superpower', 'supernatural'],
#  482: ['comedy', 'historical', 'parody'],
#  483: ['action',
#   'adventure',
#   'demons',
#   'drama',
#   'fantasy',
#   'horror',
#   'military',
#   'seinen',
#   'supernatural'],
#  484: ['action', 'adventure', 'comedy', 'supernatural', 'shounen'],
#  485: ['action', 'adventure', 'superpower', 'shounen'],
#  486: ['action', 'demons', 'shounen', 'supernatural'],
#  487: ['action', 'adventure', 'shounen', 'superpower'],
#  488: ['action', 'fantasy', 'superpower'],
#  489: ['action', 'demons', 'shounen', 'supernatural'],
#  490: ['drama', 'fantasy', 'shoujo', 'sliceoflife', 'supernatural'],
#  491: ['action', 'military', 'police', 'scifi'],
#  492: ['action', 'adventure', 'comedy', 'fantasy', 'kids'],
#  493: ['action', 'adventure', 'seinen'],
#  494: ['comedy', 'shounen', 'sports'],
#  495: ['adventure', 'game', 'shounen'],
#  496: ['adventure', 'romance', 'fantasy', 'shoujo'],
#  497: ['comedy', 'historical', 'romance'],
#  498: ['action',
#   'adventure',
#   'comedy',
#   'drama',
#   'historical',
#   'military',
#   'romance'],
#  499: ['action', 'adventure', 'historical', 'drama', 'romance', 'fantasy'],
#  500: ['drama', 'music', 'romance', 'sliceoflife'],
#  501: ['drama', 'josei', 'romance', 'sliceoflife'],
#  502: ['action', 'adventure', 'comedy', 'romance', 'fantasy'],
#  503: ['sliceoflife', 'comedy'],
#  504: ['sliceoflife', 'comedy', 'school', 'shounen'],
#  505: ['adventure', 'comedy', 'supernatural', 'magic', 'fantasy'],
#  506: ['action', 'sports', 'comedy', 'shounen'],
#  507: ['action', 'adventure', 'drama', 'romance', 'fantasy', 'shounen'],
#  508: ['sliceoflife', 'supernatural', 'drama', 'romance'],
#  509: ['comedy', 'drama', 'romance', 'school', 'sports'],
#  510: ['adventure', 'comedy', 'fantasy', 'magic', 'supernatural'],
#  511: ['action', 'supernatural', 'drama', 'romance', 'fantasy'],
#  512: ['sliceoflife', 'comedy', 'martialarts', 'fantasy'],
#  513: ['sliceoflife', 'comedy', 'romance', 'school'],
#  514: ['action', 'comedy', 'ecchi', 'harem', 'superpower'],
#  515: ['sliceoflife', 'comedy', 'romance', 'school', 'seinen'],
#  516: ['comedy', 'romance', 'school'],
#  517: ['comedy', 'romance', 'school', 'shounen', 'sliceoflife'],
#  518: ['action', 'adventure', 'superpower'],
#  519: ['comedy', 'drama', 'magic', 'romance', 'fantasy'],
#  520: ['comedy', 'ecchi', 'harem', 'romance', 'school'],
#  521: ['action',
#   'comedy',
#   'parody',
#   'scifi',
#   'seinen',
#   'superpower',
#   'supernatural'],
#  522: ['action', 'mecha', 'military', 'music', 'romance', 'scifi', 'space'],
#  523: ['sliceoflife', 'comedy', 'school', 'shoujoai'],
#  524: ['scifi',
#   'adventure',
#   'mystery',
#   'superpower',
#   'supernatural',
#   'school'],
#  525: ['action', 'comedy', 'sports', 'school', 'shounen'],
#  526: ['comedy', 'romance', 'school', 'shoujo'],
#  527: ['action', 'scifi', 'adventure'],
#  528: ['scifi', 'comedy', 'superpower', 'supernatural', 'romance'],
#  529: ['fantasy', 'historical'],
#  530: ['action', 'space', 'mecha', 'romance', 'military', 'drama', 'scifi'],
#  531: ['sliceoflife', 'romance', 'school', 'shounenai'],
#  532: ['action',
#   'military',
#   'adventure',
#   'demons',
#   'supernatural',
#   'fantasy',
#   'seinen'],
#  533: ['action', 'supernatural', 'romance', 'fantasy', 'shounen'],
#  534: ['sliceoflife', 'comedy', 'supernatural', 'drama', 'school'],
#  535: ['comedy', 'drama', 'shounen', 'sports'],
#  536: ['action', 'harem', 'comedy', 'parody', 'romance', 'shounen'],
#  537: ['supernatural', 'drama', 'school'],
#  538: ['comedy', 'demons', 'supernatural', 'romance', 'fantasy', 'shoujo'],
#  539: ['scifi', 'harem', 'comedy', 'ecchi', 'school', 'shounen'],
#  540: ['comedy', 'parody'],
#  541: ['comedy', 'demons', 'supernatural', 'school', 'shounen'],
#  542: ['mystery', 'horror', 'psychological', 'supernatural'],
#  543: ['action', 'drama', 'scifi', 'seinen', 'superpower'],
#  544: ['comedy', 'drama', 'romance', 'fantasy'],
#  545: ['scifi', 'sliceoflife'],
#  546: ['action', 'harem', 'comedy', 'magic', 'ecchi', 'fantasy', 'school'],
#  547: ['action', 'cars', 'sports', 'drama', 'seinen'],
#  548: ['comedy', 'game', 'shounen', 'supernatural'],
#  549: ['action', 'comedy', 'ecchi', 'fantasy', 'harem', 'mecha', 'school'],
#  550: ['military', 'adventure', 'drama', 'magic', 'fantasy', 'shounen'],
#  551: ['sliceoflife', 'comedy', 'romance', 'seinen'],
#  552: ['mystery'],
#  553: ['action',
#   'adventure',
#   'fantasy',
#   'magic',
#   'romance',
#   'supernatural',
#   'shounen'],
#  554: ['harem', 'comedy', 'parody', 'fantasy'],
#  555: ['action', 'drama', 'mecha', 'scifi', 'space'],
#  556: ['adventure',
#   'fantasy',
#   'historical',
#   'mystery',
#   'seinen',
#   'sliceoflife',
#   'supernatural'],
#  557: ['action',
#   'comedy',
#   'ecchi',
#   'fantasy',
#   'harem',
#   'romance',
#   'school',
#   'scifi',
#   'supernatural'],
#  558: ['romance', 'school', 'sliceoflife'],
#  559: ['drama', 'military', 'romance', 'scifi'],
#  560: ['adventure', 'comedy', 'scifi', 'shounen', 'superpower'],
#  561: ['harem', 'comedy', 'romance', 'school', 'shounen'],
#  562: ['sliceoflife', 'comedy'],
#  563: ['action', 'comedy', 'martialarts'],
#  564: ['comedy', 'ecchi', 'fantasy', 'harem', 'romance', 'school', 'vampire'],
#  565: ['sports', 'school', 'shounen'],
#  566: ['action', 'scifi', 'adventure', 'comedy', 'drama', 'shounen'],
#  567: ['action', 'adventure', 'supernatural', 'shounen'],
#  568: ['adventure', 'comedy', 'magic', 'fantasy', 'school'],
#  569: ['adventure', 'fantasy', 'scifi', 'shounen'],
#  570: ['comedy', 'parody', 'supernatural'],
#  571: ['action', 'cars', 'sports', 'drama', 'seinen'],
#  572: ['action', 'comedy', 'superpower', 'supernatural', 'shounen'],
#  573: ['sliceoflife', 'comedy', 'drama', 'romance', 'josei'],
#  574: ['comedy', 'sports', 'school', 'shounen'],
#  575: ['action', 'comedy', 'superpower', 'school'],
#  576: ['comedy', 'shoujo'],
#  577: ['action', 'mystery', 'horror', 'psychological'],
#  578: ['action', 'adventure', 'magic', 'fantasy'],
#  579: ['action', 'harem', 'demons', 'romance', 'ecchi', 'fantasy'],
#  580: ['action', 'mystery', 'horror', 'psychological', 'school'],
#  581: ['action', 'mystery', 'superpower', 'thriller'],
#  582: ['sliceoflife', 'comedy', 'school'],
#  583: ['action',
#   'scifi',
#   'comedy',
#   'historical',
#   'parody',
#   'samurai',
#   'shounen'],
#  584: ['action', 'military', 'scifi', 'space', 'drama', 'mecha'],
#  585: ['comedy', 'romance', 'school'],
#  586: ['action', 'adventure', 'comedy', 'drama', 'fantasy', 'kids'],
#  587: ['adventure', 'comedy', 'drama', 'mystery', 'scifi'],
#  588: ['adventure',
#   'sliceoflife',
#   'mystery',
#   'historical',
#   'supernatural',
#   'fantasy',
#   'seinen'],
#  589: ['action', 'adventure', 'superpower', 'demons', 'shounen'],
#  590: ['action', 'scifi', 'supernatural', 'school', 'shounen'],
#  591: ['comedy', 'sports', 'drama', 'shounen'],
#  592: ['mecha', 'military', 'mystery', 'police', 'scifi', 'seinen'],
#  593: ['comedy', 'drama', 'mystery', 'romance', 'sliceoflife', 'thriller'],
#  594: ['sliceoflife', 'comedy', 'supernatural', 'romance', 'school'],
#  595: ['comedy', 'shounen', 'sports'],
#  596: ['action', 'drama', 'fantasy', 'horror', 'romance', 'scifi', 'vampire'],
#  597: ['comedy', 'parody', 'school'],
#  598: ['harem', 'comedy', 'romance', 'ecchi', 'school', 'seinen'],
#  599: ['mystery', 'police', 'psychological', 'supernatural', 'thriller'],
#  600: ['action', 'adventure', 'samurai'],
#  601: ['drama', 'fantasy', 'historical', 'romance'],
#  602: ['sliceoflife', 'comedy', 'romance'],
#  603: ['comedy', 'seinen', 'sliceoflife'],
#  604: ['action',
#   'adventure',
#   'supernatural',
#   'magic',
#   'ecchi',
#   'fantasy',
#   'shounen'],
#  605: ['sliceoflife', 'comedy', 'supernatural', 'magic', 'shounen'],
#  606: ['comedy', 'sliceoflife'],
#  607: ['fantasy', 'scifi', 'shounen', 'sliceoflife'],
#  608: ['sliceoflife', 'romance'],
#  609: ['sliceoflife', 'comedy', 'parody'],
#  610: ['action', 'harem', 'comedy', 'superpower', 'ecchi'],
#  611: ['drama'],
#  612: ['psychological', 'historical', 'thriller', 'drama', 'seinen'],
#  613: ['comedy', 'magic', 'ecchi', 'fantasy', 'shounen'],
#  614: ['mystery', 'comedy', 'superpower', 'drama'],
#  615: ['action', 'drama', 'scifi', 'shounen', 'sliceoflife', 'sports'],
#  616: ['music', 'sliceoflife', 'comedy', 'school'],
#  617: ['action', 'comedy', 'drama', 'magic', 'seinen'],
#  618: ['sliceoflife', 'comedy', 'demons', 'drama', 'fantasy'],
#  619: ['comedy', 'school', 'seinen'],
#  620: ['adventure', 'comedy', 'drama', 'fantasy', 'shounen'],
#  621: ['comedy', 'ecchi', 'harem', 'romance', 'school', 'scifi', 'shounen'],
#  622: ['comedy', 'romance', 'ecchi', 'school', 'seinen'],
#  623: ['action', 'adventure', 'fantasy', 'magic', 'supernatural'],
#  624: ['romance', 'school', 'shounen', 'sports'],
#  625: ['comedy', 'magic', 'school', 'shoujo'],
#  626: ['music', 'school', 'sliceoflife'],
#  627: ['comedy', 'drama', 'romance', 'sports'],
#  628: ['action', 'adventure', 'comedy', 'demons', 'shounen', 'supernatural'],
#  629: ['action', 'historical', 'military', 'seinen'],
#  630: ['action',
#   'adventure',
#   'historical',
#   'supernatural',
#   'romance',
#   'samurai',
#   'fantasy'],
#  631: ['sliceoflife', 'comedy'],
#  632: ['comedy', 'school', 'shounen'],
#  633: ['action', 'ecchi', 'fantasy', 'school'],
#  634: ['action', 'magic', 'mystery', 'romance', 'supernatural', 'thriller'],
#  635: ['sliceoflife', 'comedy'],
#  636: ['comedy', 'parody', 'romance'],
#  637: ['action', 'comedy', 'drama', 'mystery', 'romance', 'thriller'],
#  638: ['comedy', 'scifi', 'sliceoflife', 'sports'],
#  639: ['adventure', 'romance', 'fantasy'],
#  640: ['action', 'military', 'historical', 'seinen'],
#  641: ['action', 'comedy', 'historical', 'demons', 'supernatural', 'fantasy'],
#  642: ['action', 'fantasy', 'magic', 'supernatural'],
#  643: ['drama', 'magic', 'romance', 'shoujo'],
#  644: ['action', 'adventure'],
#  645: ['action', 'scifi', 'drama', 'fantasy'],
#  646: ['comedy', 'drama', 'romance', 'school'],
#  647: ['comedy', 'drama', 'romance', 'school', 'shounen', 'sliceoflife'],
#  648: ['comedy', 'romance', 'shounenai'],
#  649: ['action', 'drama', 'mecha', 'scifi', 'space'],
#  650: ['historical', 'romance', 'school', 'shoujo'],
#  651: ['comedy', 'romance', 'school'],
#  652: ['fantasy', 'mystery'],
#  653: ['sliceoflife', 'drama', 'romance', 'shoujo'],
#  654: ['action', 'scifi', 'seinen'],
#  655: ['adventure', 'comedy', 'demons', 'magic', 'fantasy'],
#  656: ['action', 'scifi', 'psychological', 'drama'],
#  657: ['drama', 'romance', 'school'],
#  658: ['adventure', 'psychological', 'romance', 'fantasy', 'mecha', 'shoujo'],
#  659: ['action', 'adventure', 'comedy', 'demons', 'supernatural', 'shounen'],
#  660: ['sports', 'military', 'school'],
#  661: ['action',
#   'scifi',
#   'comedy',
#   'historical',
#   'parody',
#   'samurai',
#   'shounen'],
#  662: ['scifi',
#   'harem',
#   'comedy',
#   'supernatural',
#   'romance',
#   'ecchi',
#   'fantasy',
#   'school'],
#  663: ['scifi', 'comedy', 'parody'],
#  664: ['action',
#   'adventure',
#   'martialarts',
#   'shounen',
#   'superpower',
#   'supernatural'],
#  665: ['scifi', 'sliceoflife', 'comedy'],
#  666: ['music', 'comedy', 'supernatural', 'drama', 'romance', 'shoujo'],
#  667: ['comedy', 'shounen', 'supernatural'],
#  668: ['drama', 'shounen', 'sports'],
#  669: ['comedy', 'school', 'shoujoai', 'sliceoflife'],
#  670: ['action', 'adventure', 'comedy', 'drama', 'fantasy', 'shounen'],
#  671: ['scifi', 'adventure', 'comedy', 'magic'],
#  672: ['comedy',
#   'drama',
#   'ecchi',
#   'harem',
#   'romance',
#   'scifi',
#   'shounen',
#   'supernatural'],
#  673: ['comedy', 'drama', 'romance', 'school', 'shoujo', 'sliceoflife'],
#  674: ['sports', 'romance', 'school', 'shounen'],
#  675: ['adventure', 'mystery', 'police', 'shounen'],
#  676: ['action', 'scifi', 'space', 'mecha', 'seinen'],
#  677: ['game', 'comedy', 'romance', 'ecchi', 'school'],
#  678: ['action', 'drama', 'horror', 'school', 'seinen', 'supernatural'],
#  679: ['comedy',
#   'drama',
#   'ecchi',
#   'fantasy',
#   'harem',
#   'magic',
#   'romance',
#   'school',
#   'seinen'],
#  680: ['mystery', 'thriller', 'school'],
#  681: ['action', 'adventure', 'fantasy', 'school', 'scifi'],
#  682: ['action', 'comedy', 'fantasy', 'sliceoflife', 'supernatural'],
#  683: ['action', 'adventure', 'fantasy', 'magic', 'comedy', 'shounen'],
#  684: ['action', 'scifi', 'police', 'psychological', 'mecha', 'seinen'],
#  685: ['action', 'drama', 'mecha', 'military', 'scifi', 'space'],
#  686: ['romance', 'samurai', 'historical', 'drama', 'shounen'],
#  687: ['action', 'fantasy', 'supernatural'],
#  688: ['adventure', 'ecchi', 'fantasy', 'harem', 'romance'],
#  689: ['comedy', 'school', 'shounen', 'sliceoflife'],
#  690: ['action', 'cars', 'sports', 'drama', 'romance', 'seinen'],
#  691: ['action', 'military', 'scifi'],
#  692: ['action', 'sports', 'ecchi', 'shounen'],
#  693: ['military', 'police', 'psychological', 'drama', 'romance'],
#  694: ['comedy', 'romance', 'school'],
#  695: ['mystery', 'comedy', 'supernatural'],
#  696: ['demons', 'magic', 'romance', 'shoujo'],
#  697: ['action', 'drama', 'school', 'sliceoflife'],
#  698: ['comedy', 'ecchi', 'harem', 'romance', 'shounen', 'sliceoflife'],
#  699: ['action', 'harem', 'comedy', 'parody', 'romance', 'shounen'],
#  700: ['action', 'adventure', 'fantasy', 'magic', 'shounen'],
#  701: ['comedy', 'school', 'shounen', 'sliceoflife'],
#  702: ['sliceoflife', 'comedy'],
#  703: ['scifi', 'comedy', 'parody'],
#  704: ['comedy', 'school', 'superpower'],
#  705: ['comedy', 'drama', 'romance', 'shounenai'],
#  706: ['action', 'comedy', 'romance', 'school'],
#  707: ['adventure',
#   'comedy',
#   'drama',
#   'fantasy',
#   'magic',
#   'romance',
#   'shoujo'],
#  708: ['comedy', 'shounen', 'sliceoflife'],
#  709: ['action', 'adventure', 'comedy', 'fantasy', 'shounen'],
#  710: ['action',
#   'adventure',
#   'comedy',
#   'fantasy',
#   'martialarts',
#   'shounen',
#   'superpower'],
#  711: ['action', 'comedy', 'fantasy', 'shoujo'],
#  712: ['drama', 'mecha', 'psychological', 'scifi'],
#  713: ['comedy', 'demons', 'ecchi', 'romance', 'school'],
#  714: ['sliceoflife', 'comedy', 'supernatural', 'school', 'shounen'],
#  715: ['mystery', 'comedy', 'psychological', 'supernatural', 'thriller'],
#  716: ['action', 'psychological', 'military', 'drama', 'scifi'],
#  717: ['action', 'adventure', 'mystery', 'comedy', 'seinen'],
#  718: ['action', 'mecha', 'military', 'scifi'],
#  719: ['sports', 'comedy', 'drama', 'shounen'],
#  720: ['action',
#   'adventure',
#   'martialarts',
#   'superpower',
#   'mystery',
#   'shounen'],
#  721: ['action', 'adventure', 'comedy', 'drama', 'fantasy', 'kids'],
#  722: ['comedy', 'drama', 'sports'],
#  723: ['harem', 'comedy', 'parody', 'school'],
#  724: ['comedy', 'demons', 'supernatural', 'romance', 'fantasy', 'shoujo'],
#  725: ['action', 'comedy', 'drama', 'magic', 'seinen'],
#  726: ['action', 'adventure', 'psychological', 'supernatural'],
#  727: ['action', 'psychological', 'horror', 'mystery'],
#  728: ['action', 'demons', 'fantasy', 'josei', 'magic', 'military'],
#  729: ['harem', 'comedy', 'romance', 'school', 'shoujo'],
#  730: ['comedy', 'drama', 'music'],
#  731: ['action',
#   'scifi',
#   'harem',
#   'drama',
#   'romance',
#   'ecchi',
#   'martialarts',
#   'seinen'],
#  732: ['drama', 'fantasy', 'shoujo', 'sliceoflife', 'supernatural'],
#  733: ['mystery'],
#  734: ['action', 'military', 'romance'],
#  735: ['action', 'demons', 'fantasy'],
#  736: ['sliceoflife', 'comedy', 'school'],
#  737: ['sports', 'comedy', 'school', 'shounen'],
#  738: ['action',
#   'comedy',
#   'drama',
#   'mecha',
#   'military',
#   'scifi',
#   'shounen',
#   'space'],
#  739: ['harem', 'comedy', 'ecchi', 'school'],
#  740: ['action', 'adventure', 'comedy', 'space'],
#  741: ['comedy', 'drama', 'romance', 'school', 'shounen', 'sliceoflife'],
#  742: ['scifi', 'psychological', 'drama', 'mecha'],
#  743: ['mystery', 'supernatural'],
#  744: ['action'],
#  745: ['adventure', 'comedy', 'demons', 'magic', 'fantasy'],
#  746: ['sliceoflife', 'comedy', 'drama', 'romance', 'school'],
#  747: ['action', 'mecha', 'scifi', 'space'],
#  748: ['action', 'adventure', 'demons', 'supernatural', 'magic', 'fantasy'],
#  749: ['action',
#   'adventure',
#   'fantasy',
#   'romance',
#   'supernatural',
#   'drama',
#   'mystery',
#   'shounen'],
#  750: ['action',
#   'adventure',
#   'mystery',
#   'supernatural',
#   'drama',
#   'magic',
#   'romance',
#   'fantasy',
#   'shounen'],
#  751: ['comedy', 'school', 'music', 'sliceoflife'],
#  752: ['action',
#   'adventure',
#   'martialarts',
#   'shounen',
#   'superpower',
#   'supernatural'],
#  753: ['comedy', 'ecchi', 'harem', 'seinen', 'sliceoflife'],
#  754: ['comedy', 'romance'],
#  755: ['comedy', 'sports'],
#  756: ['comedy', 'shounen'],
#  757: ['adventure', 'drama', 'music', 'scifi'],
#  758: ['comedy', 'romance', 'school', 'shounen'],
#  759: ['comedy', 'drama', 'romance', 'ecchi'],
#  760: ['action', 'mecha', 'military'],
#  761: ['parody', 'comedy', 'school'],
#  762: ['action', 'adventure', 'comedy', 'fantasy', 'shounen', 'superpower'],
#  763: ['fantasy', 'scifi', 'shounen', 'sliceoflife'],
#  764: ['action', 'historical', 'supernatural', 'drama', 'samurai', 'josei'],
#  765: ['cars', 'seinen', 'sports'],
#  766: ['drama', 'mystery', 'scifi', 'seinen'],
#  767: ['action', 'supernatural', 'vampire'],
#  768: ['mystery', 'comedy', 'psychological', 'supernatural', 'drama'],
#  769: ['action', 'cars', 'sports', 'drama', 'seinen'],
#  770: ['sliceoflife', 'comedy', 'romance', 'seinen'],
#  771: ['scifi', 'adventure'],
#  772: ['action', 'sports', 'school', 'shounen'],
#  773: ['adventure',
#   'comedy',
#   'demons',
#   'drama',
#   'fantasy',
#   'historical',
#   'romance',
#   'shounen',
#   'supernatural'],
#  774: ['military', 'scifi', 'music', 'sliceoflife'],
#  775: ['action', 'scifi', 'comedy', 'historical', 'parody'],
#  776: ['action', 'mystery', 'historical'],
#  777: ['comedy', 'ecchi', 'harem', 'romance', 'school', 'seinen'],
#  778: ['action', 'adventure', 'martialarts', 'shounen', 'superpower'],
#  779: ['adventure', 'fantasy', 'comedy', 'romance', 'historical', 'drama'],
#  780: ['comedy', 'parody'],
#  781: ['action', 'scifi', 'adventure', 'comedy', 'fantasy', 'shounen'],
#  782: ['action', 'comedy', 'drama', 'magic', 'superpower'],
#  783: ['action', 'historical', 'martialarts', 'samurai', 'superpower'],
#  784: ['action', 'comedy', 'magic', 'romance', 'fantasy', 'school', 'shoujo'],
#  785: ['josei', 'sliceoflife'],
#  786: ['sliceoflife', 'comedy'],
#  787: ['drama', 'romance', 'school'],
#  788: ['horror', 'mystery', 'thriller'],
#  789: ['action', 'supernatural', 'drama', 'magic', 'fantasy'],
#  790: ['sliceoflife', 'comedy', 'romance', 'school'],
#  791: ['action',
#   'comedy',
#   'drama',
#   'mystery',
#   'shounen',
#   'superpower',
#   'supernatural'],
#  792: ['military', 'scifi', 'adventure', 'drama', 'romance', 'mecha'],
#  793: ['comedy', 'parody', 'sliceoflife'],
#  794: ['sliceoflife', 'drama', 'romance', 'school'],
#  795: ['romance', 'seinen'],
#  796: ['action', 'comedy', 'drama'],
#  797: ['action', 'space', 'mecha', 'military', 'scifi'],
#  798: ['mystery', 'horror', 'psychological', 'supernatural'],
#  799: ['sliceoflife', 'comedy', 'shounen'],
#  800: ['adventure', 'comedy', 'fantasy', 'shounen'],
#  801: ['scifi', 'adventure', 'psychological', 'supernatural', 'drama'],
#  802: ['adventure', 'comedy', 'romance', 'shounen'],
#  803: ['action',
#   'adventure',
#   'comedy',
#   'fantasy',
#   'magic',
#   'scifi',
#   'shounen',
#   'superpower'],
#  804: ['action', 'comedy', 'martialarts', 'shounen', 'superpower'],
#  805: ['fantasy', 'scifi', 'shounen', 'sliceoflife'],
#  806: ['horror', 'psychological', 'supernatural', 'drama', 'ecchi'],
#  807: ['action', 'scifi', 'seinen'],
#  808: ['adventure', 'supernatural', 'fantasy', 'shounen'],
#  809: ['action', 'mecha', 'military', 'music', 'romance', 'scifi', 'space'],
#  810: ['comedy', 'romance', 'school'],
#  811: ['action', 'adventure', 'drama', 'psychological', 'scifi'],
#  812: ['adventure', 'drama', 'fantasy', 'shounen'],
#  813: ['mystery', 'comedy', 'psychological', 'supernatural', 'drama'],
#  814: ['adventure',
#   'fantasy',
#   'magic',
#   'martialarts',
#   'comedy',
#   'romance',
#   'historical',
#   'drama',
#   'shoujo'],
#  815: ['comedy', 'drama', 'fantasy', 'magic', 'shoujo'],
#  816: ['action', 'fantasy', 'supernatural', 'comedy', 'drama', 'shounen'],
#  817: ['comedy', 'romance'],
#  818: ['mystery', 'police', 'drama', 'fantasy', 'seinen'],
#  819: ['comedy', 'supernatural', 'magic', 'romance', 'seinen'],
#  820: ['action',
#   'harem',
#   'comedy',
#   'supernatural',
#   'romance',
#   'ecchi',
#   'fantasy',
#   'school'],
#  821: ['action', 'scifi', 'mecha'],
#  822: ['action',
#   'adventure',
#   'historical',
#   'supernatural',
#   'drama',
#   'fantasy',
#   'shounen'],
#  823: ['sliceoflife', 'comedy', 'fantasy'],
#  824: ['action', 'superpower', 'supernatural', 'shounen'],
#  825: ['action', 'fantasy', 'magic', 'supernatural'],
#  826: ['adventure', 'police', 'comedy', 'mystery', 'shounen'],
#  827: ['action', 'fantasy', 'mecha', 'military', 'shounen'],
#  828: ['adventure',
#   'demons',
#   'drama',
#   'fantasy',
#   'historical',
#   'romance',
#   'shounen',
#   'supernatural'],
#  829: ['comedy', 'demons', 'supernatural', 'fantasy', 'seinen'],
#  830: ['scifi', 'harem', 'comedy', 'romance', 'school'],
#  831: ['comedy', 'ecchi', 'harem', 'school', 'scifi', 'shounen'],
#  832: ['comedy', 'sports', 'drama', 'fantasy', 'shoujo'],
#  833: ['action', 'adventure', 'supernatural', 'magic', 'fantasy', 'shounen'],
#  834: ['sliceoflife', 'comedy', 'romance', 'school'],
#  835: ['action',
#   'comedy',
#   'ecchi',
#   'martialarts',
#   'school',
#   'shounen',
#   'superpower'],
#  836: ['historical', 'drama', 'seinen'],
#  837: ['action', 'fantasy', 'mecha', 'military', 'shounen'],
#  838: ['action', 'harem', 'comedy', 'supernatural', 'magic', 'ecchi'],
#  839: ['adventure', 'mystery', 'comedy', 'supernatural'],
#  840: ['action', 'supernatural', 'fantasy'],
#  841: ['comedy', 'school', 'sliceoflife'],
#  842: ['historical', 'mecha', 'samurai', 'scifi'],
#  843: ['adventure', 'comedy', 'kids', 'drama', 'fantasy'],
#  844: ['comedy', 'school'],
#  845: ['action', 'fantasy', 'josei', 'mystery', 'scifi'],
#  846: ['action', 'fantasy', 'kids', 'scifi'],
#  847: ['music', 'shounen'],
#  848: ['comedy', 'school', 'shoujo', 'superpower'],
#  849: ['action',
#   'adventure',
#   'comedy',
#   'drama',
#   'fantasy',
#   'shounen',
#   'superpower'],
#  850: ['action', 'police', 'mystery', 'shounen'],
#  851: ['action', 'fantasy', 'mecha', 'military', 'shounen'],
#  852: ['action', 'comedy', 'sports', 'shounen'],
#  853: ['sports', 'superpower', 'shounen'],
#  854: ['comedy', 'romance', 'school'],
#  855: ['comedy', 'ecchi', 'romance', 'supernatural'],
#  856: ['adventure', 'comedy', 'demons', 'fantasy', 'shoujo'],
#  857: ['adventure',
#   'historical',
#   'horror',
#   'supernatural',
#   'romance',
#   'samurai',
#   'fantasy',
#   'shounen'],
#  858: ['adventure', 'mystery', 'comedy', 'police', 'shounen'],
#  859: ['mystery', 'supernatural'],
#  860: ['mystery', 'comedy', 'superpower', 'drama'],
#  861: ['adventure', 'comedy', 'fantasy', 'shounen'],
#  862: ['sliceoflife', 'romance', 'school', 'shoujo'],
#  863: ['mystery', 'psychological', 'supernatural'],
#  864: ['action',
#   'mystery',
#   'horror',
#   'psychological',
#   'supernatural',
#   'drama'],
#  865: ['action', 'mecha', 'military', 'shounen'],
#  866: ['military', 'historical', 'drama', 'romance', 'shoujo'],
#  867: ['comedy', 'drama', 'romance', 'ecchi', 'shounen'],
#  868: ['scifi', 'adventure', 'shounen'],
#  869: ['comedy', 'drama', 'romance'],
#  870: ['action', 'harem', 'supernatural', 'romance', 'ecchi', 'school'],
#  871: ['action', 'sliceoflife', 'drama', 'school'],
#  872: ['comedy', 'harem', 'romance', 'school', 'shounen'],
#  873: ['action', 'fantasy', 'mecha', 'military', 'shounen'],
#  874: ['scifi', 'drama', 'romance', 'shoujo'],
#  875: ['fantasy', 'sliceoflife', 'supernatural'],
#  876: ['action', 'adventure', 'comedy', 'drama'],
#  877: ['comedy', 'romance', 'school', 'shoujo', 'sliceoflife'],
#  878: ['comedy'],
#  879: ['action',
#   'comedy',
#   'drama',
#   'fantasy',
#   'magic',
#   'mecha',
#   'romance',
#   'school',
#   'shoujoai'],
#  880: ['sliceoflife', 'drama', 'romance', 'school'],
#  881: ['drama', 'fantasy', 'sliceoflife'],
#  882: ['adventure', 'mystery', 'comedy', 'police', 'shounen'],
#  883: ['scifi', 'space', 'drama', 'romance', 'mecha'],
#  884: ['adventure', 'comedy', 'fantasy', 'scifi', 'shounen'],
#  885: ['action', 'adventure', 'comedy', 'romance', 'fantasy'],
#  886: ['action', 'harem', 'demons', 'romance', 'ecchi', 'fantasy'],
#  887: ['adventure', 'drama', 'fantasy', 'military', 'scifi'],
#  888: ['action', 'adventure', 'sliceoflife'],
#  889: ['action',
#   'mystery',
#   'police',
#   'psychological',
#   'supernatural',
#   'thriller'],
#  890: ['comedy', 'school', 'shounen', 'supernatural'],
#  891: ['action', 'fantasy', 'magic', 'seinen', 'supernatural'],
#  892: ['action', 'scifi', 'superpower', 'magic'],
#  893: ['ecchi', 'comedy', 'harem', 'romance', 'demons', 'school'],
#  894: ['comedy', 'parody'],
#  895: ['horror', 'mystery', 'supernatural', 'vampire'],
#  896: ['comedy', 'historical', 'demons', 'supernatural', 'fantasy', 'shounen'],
#  897: ['action', 'mecha', 'military', 'scifi', 'space'],
#  898: ['music', 'sliceoflife', 'school'],
#  899: ['action', 'supernatural', 'vampire'],
#  900: ['comedy',
#   'drama',
#   'harem',
#   'magic',
#   'music',
#   'romance',
#   'school',
#   'shoujo'],
#  901: ['sliceoflife', 'psychological', 'romance'],
#  902: ['comedy', 'romance', 'vampire', 'school', 'shounen'],
#  903: ['action', 'supernatural', 'fantasy'],
#  904: ['drama', 'romance', 'fantasy', 'school'],
#  905: ['action', 'space', 'mecha', 'military', 'drama', 'scifi'],
#  906: ['scifi', 'comedy', 'drama', 'romance', 'school'],
#  907: ['action', 'game', 'comedy', 'fantasy', 'shounen'],
#  908: ['sliceoflife', 'comedy'],
#  909: ['adventure', 'mystery', 'comedy', 'police', 'shounen'],
#  910: ['comedy', 'school', 'sliceoflife'],
#  911: ['action', 'scifi', 'drama', 'martialarts', 'shounen'],
#  912: ['action',
#   'comedy',
#   'ecchi',
#   'martialarts',
#   'school',
#   'shounen',
#   'superpower'],
#  913: ['mystery', 'psychological', 'scifi', 'supernatural'],
#  914: ['drama', 'magic', 'romance', 'shoujo'],
#  915: ['action', 'fantasy', 'harem', 'romance', 'school', 'supernatural'],
#  916: ['sliceoflife', 'fantasy', 'seinen'],
#  917: ['action', 'harem', 'comedy', 'supernatural', 'magic', 'ecchi'],
#  918: ['comedy', 'parody', 'school'],
#  919: ['scifi', 'adventure', 'comedy', 'kids'],
#  920: ['action', 'drama', 'historical', 'josei', 'samurai', 'supernatural'],
#  921: ['action', 'comedy', 'drama', 'magic', 'seinen'],
#  922: ['action', 'game', 'military', 'scifi', 'fantasy'],
#  923: ['mystery', 'horror', 'supernatural'],
#  924: ['sliceoflife', 'comedy', 'romance', 'school', 'seinen', 'shoujoai'],
#  925: ['action', 'comedy', 'ecchi', 'scifi', 'superpower'],
#  926: ['sports', 'shounen'],
#  927: ['comedy', 'shoujoai', 'sliceoflife'],
#  928: ['drama', 'romance', 'sliceoflife'],
#  929: ['harem', 'romance', 'scifi'],
#  930: ['comedy', 'drama', 'romance', 'shoujo'],
#  931: ['action', 'fantasy'],
#  932: ['horror', 'mystery', 'shoujo', 'supernatural'],
#  933: ['comedy', 'school', 'seinen', 'sliceoflife'],
#  934: ['comedy', 'parody', 'scifi', 'shounen'],
#  935: ['comedy', 'parody', 'romance', 'school'],
#  936: ['demons',
#   'historical',
#   'military',
#   'romance',
#   'seinen',
#   'supernatural'],
#  937: ['action', 'adventure', 'comedy', 'ecchi', 'scifi', 'shounen'],
#  938: ['comedy', 'school', 'shoujo', 'sliceoflife'],
#  939: ['music', 'sliceoflife', 'school'],
#  940: ['comedy', 'romance', 'ecchi', 'school', 'seinen'],
#  941: ['adventure', 'mystery', 'comedy', 'police', 'shounen'],
#  942: ['action', 'comedy', 'school', 'shounen', 'superpower', 'supernatural'],
#  943: ['comedy', 'psychological', 'drama', 'seinen'],
#  944: ['sliceoflife', 'comedy', 'school', 'seinen'],
#  945: ['comedy', 'seinen', 'sliceoflife'],
#  946: ['action', 'military', 'space', 'mecha'],
#  947: ['comedy', 'drama', 'romance', 'shounenai'],
#  948: ['action', 'demons', 'supernatural', 'magic', 'fantasy'],
#  949: ['action', 'historical', 'shoujo', 'supernatural'],
#  950: ['action', 'adventure', 'fantasy'],
#  951: ['drama', 'historical', 'romance', 'scifi', 'shounenai'],
#  952: ['drama', 'romance', 'school'],
#  953: ['action', 'adventure', 'comedy', 'fantasy', 'shounen'],
#  954: ['sliceoflife', 'mystery', 'school'],
#  955: ['game', 'psychological'],
#  956: ['comedy', 'magic', 'school', 'shoujo'],
#  957: ['action', 'adventure', 'comedy', 'drama'],
#  958: ['action', 'military', 'comedy', 'shoujo'],
#  959: ['military', 'scifi', 'space', 'drama', 'romance', 'mecha'],
#  960: ['adventure', 'comedy', 'fantasy', 'magic', 'romance', 'shoujo'],
#  961: ['comedy', 'school', 'shoujo'],
#  962: ['action', 'mecha', 'military', 'shounen'],
#  963: ['scifi', 'mystery', 'psychological'],
#  964: ['comedy', 'romance', 'ecchi', 'fantasy'],
#  965: ['adventure', 'comedy', 'fantasy', 'shounen'],
#  966: ['sliceoflife', 'psychological', 'drama', 'magic', 'fantasy'],
#  967: ['adventure', 'comedy', 'demons', 'magic', 'fantasy', 'shounen'],
#  968: ['action', 'comedy', 'magic', 'fantasy'],
#  969: ['adventure', 'drama', 'fantasy'],
#  970: ['adventure',
#   'comedy',
#   'demons',
#   'drama',
#   'historical',
#   'romance',
#   'shounen',
#   'supernatural'],
#  971: ['adventure', 'drama', 'scifi', 'sliceoflife'],
#  972: ['ecchi', 'school', 'shounen'],
#  973: ['comedy', 'parody', 'dementia'],
#  974: ['action', 'adventure', 'comedy', 'superpower', 'fantasy', 'shounen'],
#  975: ['action', 'adventure', 'historical', 'magic', 'mystery', 'scifi'],
#  976: ['superpower', 'drama', 'school'],
#  977: ['comedy', 'drama', 'romance'],
#  978: ['action', 'comedy', 'school', 'shounen'],
#  979: ['military', 'historical', 'drama'],
#  980: ['action', 'comedy', 'magic', 'shounen', 'superpower', 'supernatural'],
#  981: ['action', 'demons', 'supernatural', 'fantasy', 'shoujo'],
#  982: ['drama', 'romance', 'school', 'shoujoai'],
#  983: ['action',
#   'drama',
#   'mecha',
#   'music',
#   'mystery',
#   'psychological',
#   'romance',
#   'scifi'],
#  984: ['scifi', 'horror', 'psychological', 'drama'],
#  985: ['action', 'adventure', 'magic', 'fantasy'],
#  986: ['action',
#   'adventure',
#   'comedy',
#   'drama',
#   'fantasy',
#   'shounen',
#   'superpower'],
#  987: ['action', 'mystery', 'historical', 'supernatural'],
#  988: ['mystery', 'historical', 'drama', 'samurai', 'seinen'],
#  989: ['action', 'scifi', 'space', 'comedy', 'drama', 'mecha'],
#  990: ['comedy', 'fantasy', 'mystery'],
#  991: ['comedy', 'historical', 'parody'],
#  992: ['action', 'adventure', 'comedy', 'magic', 'fantasy', 'shounen'],
#  993: ['sliceoflife', 'comedy'],
#  994: ['action', 'mecha', 'military', 'scifi'],
#  995: ['action', 'scifi', 'adventure', 'comedy', 'fantasy', 'shounen'],
#  996: ['action',
#   'ecchi',
#   'fantasy',
#   'harem',
#   'military',
#   'romance',
#   'supernatural'],
#  997: ['action', 'comedy', 'parody', 'fantasy', 'shounen'],
#  998: ['action', 'scifi', 'space', 'horror', 'drama', 'seinen'],
#  999: ['action', 'fantasy'],
#  ...}

# %%
#function to get recommendation based on genre
def get_genre_recommendations(genre):
    
    #checking if the genre is in the map inorder to pick the top ones
    index = []
    for i in range(data_scored.shape[0]):
        if genre in anime_map[i]:
            index.append(i)
        
    # Scores of the 10 most similar movies
    anime_index = index[0:10]

    # Movie indices
   # movie_indices = [i[0] for i in sig_scores]

    # Top 10 most similar movies
    return data_scored['title'].iloc[anime_index]

# %%
get_genre_recommendations('fantasy')
# Out:
# 1          fullmetal alchemist brotherhood
# 2                       shingeki no kyojin
# 6                         sword art online
# 8                          no game no life
# 23                     fullmetal alchemist
# 24                               one piece
# 26    rezero kara hajimeru isekai seikatsu
# 27                              fairy tail
# 33                          ao no exorcist
# 37                              soul eater
# Name: title, dtype: object
